# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import VLDF_ANN

import DataPackage as dp
import AmazonReviewsFeaturePlot as fp

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    max_feature=2000
    source_data, target_data = dp.datapackage(source='books', target='dvd', max_feature=max_feature, tfidf_setting='seperate')
    
    #source_data, target_data = DataDuplicate.DataDuplicate(source_data, target_data)
    
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        

    x_dim = max_feature
    y_dim = 2    
    d_dim = 2    
    z_dim = 50                #dimension of latent feature
    a_dim = 50               #dimension of prior of latent feature    
    h_z_dim = 500             #dimension of hidden unit  
    h_a_dim = 100
    learning_rate = 0.005
    activation = T.nnet.sigmoid

    
    struct = VLDF_ANN.VLDF_ANN_struct()    
    encoder_template = nn.NN_struct()
    
    struct.encoder1.share.layer_dim = [x_dim+d_dim, h_z_dim]
    struct.encoder1.share.activation = [activation]
    struct.encoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.share.decay = [1, 1]                
    struct.encoder1.mu.layer_dim = [h_z_dim, z_dim]
    struct.encoder1.mu.activation = [None]
    struct.encoder1.mu.learning_rate = [learning_rate]
    struct.encoder1.mu.decay = [1]      
    struct.encoder1.sigma.layer_dim = [h_z_dim, z_dim]
    struct.encoder1.sigma.activation = [None]
    struct.encoder1.sigma.learning_rate = [learning_rate]
    struct.encoder1.sigma.decay = [1]   

    struct.encoder2.share.layer_dim = [x_dim+d_dim, h_z_dim]
    struct.encoder2.share.activation = [activation]
    struct.encoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.share.decay = [1, 1]                
    struct.encoder2.mu.layer_dim = [h_z_dim, z_dim]
    struct.encoder2.mu.activation = [None]
    struct.encoder2.mu.learning_rate = [learning_rate]
    struct.encoder2.mu.decay = [1]      
    struct.encoder2.sigma.layer_dim = [h_z_dim, z_dim]
    struct.encoder2.sigma.activation = [None]
    struct.encoder2.sigma.learning_rate = [learning_rate]
    struct.encoder2.sigma.decay = [1]     
    
    struct.encoder3.share.layer_dim = [z_dim+y_dim, h_a_dim]
    struct.encoder3.share.activation = [activation]
    struct.encoder3.share.learning_rate = [learning_rate]
    struct.encoder3.share.decay = [1]                
    struct.encoder3.mu.layer_dim = [h_a_dim, a_dim]
    struct.encoder3.mu.activation = [None]
    struct.encoder3.mu.learning_rate = [learning_rate]
    struct.encoder3.mu.decay = [1]      
    struct.encoder3.sigma.layer_dim = [h_a_dim, a_dim]
    struct.encoder3.sigma.activation = [None]
    struct.encoder3.sigma.learning_rate = [learning_rate]
    struct.encoder3.sigma.decay = [1]

    struct.encoder4.share.layer_dim = [z_dim+d_dim, h_a_dim]
    struct.encoder4.share.activation = [activation]
    struct.encoder4.share.learning_rate = [learning_rate]
    struct.encoder4.share.decay = [1]                
    struct.encoder4.mu.layer_dim = [h_a_dim, a_dim]
    struct.encoder4.mu.activation = [None]
    struct.encoder4.mu.learning_rate = [learning_rate]
    struct.encoder4.mu.decay = [1]      
    struct.encoder4.sigma.layer_dim = [h_a_dim, a_dim]
    struct.encoder4.sigma.activation = [None]
    struct.encoder4.sigma.learning_rate = [learning_rate]
    struct.encoder4.sigma.decay = [1]    
    
    struct.encoder5.layer_dim = [z_dim, 50, y_dim]
    struct.encoder5.activation = [activation, T.nnet.softmax]   
    struct.encoder5.learning_rate = [learning_rate, learning_rate]
    struct.encoder5.decay = [1, 1]     

    #h_z_dim = 600
    struct.decoder1.share.layer_dim = [z_dim+z_dim, h_z_dim]
    struct.decoder1.share.activation = [activation]
    struct.decoder1.share.learning_rate = [learning_rate]
    struct.decoder1.share.decay = [1]                
    struct.decoder1.mu.layer_dim = [h_z_dim, x_dim]
    struct.decoder1.mu.activation = [None]
    struct.decoder1.mu.learning_rate = [learning_rate]
    struct.decoder1.mu.decay = [1]      
    struct.decoder1.sigma.layer_dim = [h_z_dim, x_dim]
    struct.decoder1.sigma.activation = [None]
    struct.decoder1.sigma.learning_rate = [learning_rate]
    struct.decoder1.sigma.decay = [1]      
    
    struct.decoder2.share.layer_dim = [a_dim+y_dim, h_a_dim]
    struct.decoder2.share.activation = [activation]
    struct.decoder2.share.learning_rate = [learning_rate]
    struct.decoder2.share.decay = [1]                
    struct.decoder2.mu.layer_dim = [h_a_dim, z_dim]
    struct.decoder2.mu.activation = [None]
    struct.decoder2.mu.learning_rate = [learning_rate]
    struct.decoder2.mu.decay = [1]      
    struct.decoder2.sigma.layer_dim = [h_a_dim, z_dim]
    struct.decoder2.sigma.activation = [None]
    struct.decoder2.sigma.learning_rate = [learning_rate]
    struct.decoder2.sigma.decay = [1]      

    struct.decoder3.share.layer_dim = [a_dim+d_dim, h_a_dim]
    struct.decoder3.share.activation = [activation]
    struct.decoder3.share.learning_rate = [learning_rate]
    struct.decoder3.share.decay = [1]                
    struct.decoder3.mu.layer_dim = [h_a_dim, z_dim]
    struct.decoder3.mu.activation = [None]
    struct.decoder3.mu.learning_rate = [learning_rate]
    struct.decoder3.mu.decay = [1]      
    struct.decoder3.sigma.layer_dim = [h_a_dim, z_dim]
    struct.decoder3.sigma.activation = [None]
    struct.decoder3.sigma.learning_rate = [learning_rate]
    struct.decoder3.sigma.decay = [1]     
    
    struct.DomainClassifier.layer_dim = [z_dim, 50, d_dim]
    struct.DomainClassifier.activation = [activation, T.nnet.softmax]   
    struct.DomainClassifier.learning_rate = [learning_rate, learning_rate]
    struct.DomainClassifier.decay = [1, 1]         
    
    coef = VLDF_ANN.VLDF_ANN_coef(
        alpha = 1000,
        beta = 100,
        L = 1,
        optimize = 'Adam_update'        
    )        
    
    description = 'AmazonReviews_mf%i_VLDF_ANN_%s' % (max_feature, coef.optimize) 
        
    features_model, test_model, trained_param = VLDF_ANN.VLDF_ANN_training(
        source_data=source_data,
        target_data=target_data,
        n_train_batches=20,
        n_epochs=50,
        k=10,
        struct = struct,
        coef = coef,
        description = description
    )
            
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description)
    
    train_fts_source, train_labels_source = source_data[0]
    train_fts_target, train_labels_target = target_data[0]
    
    zd_S = features_model()[6][0:sample_n, :]
    zd_T = features_model()[7][0:sample_n, :]
    
    zd_S, zd_T = util.feature_tsne(zd_S, zd_T)
    
    label_zd_S = []
    label_zd_T = []
    
    for i in range(y_dim):
        label_zd_S.append( zd_S[np.where(train_labels_source[0:sample_n,i] == 1)[0], :] )
        label_zd_T.append( zd_T[np.where(train_labels_target[0:sample_n,i] == 1)[0], :] )  
        
    #Both source, target zy feature
    title = 'Zd_feature_%s' % (description)
    fts = ()
    for i in range(y_dim):
        fts = fts+(label_zd_S[i][:,0], label_zd_S[i][:,1])
        fts = fts+(label_zd_T[i][:,0], label_zd_T[i][:,1])
    label = ['Source:negative', 'Target:negative', 'Source:positive', 'Target:positive']
    color = [1, 1, 2, 2]
    marker = [1, 2, 1, 2]
    line = False 
    legend = True
    util.data2plot(title=title, fts=fts, label=label, color=color, marker=marker, line=line, legend = legend)
# Out:
# number of minibatch at one epoch: 20, batch size source : 80, target : 80
#  validation size, S:400, T:400, test size, S:4465, T:3586
# ... building the model
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# ... training
# Initial, test accuracy: source domain :50.683091 %, target domain 49.470162 %
# epoch 1, minibatch 20/20, training loss 2317.003566, validation loss 2330.149190
#      epoch 1, minibatch 20/20, test accuracy of best model: source domain :52.743561 %, target domain 52.900167 %
# epoch 2, minibatch 20/20, training loss 2235.658445, validation loss 2256.946740
#      epoch 2, minibatch 20/20, test accuracy of best model: source domain :63.090705 %, target domain 59.118795 %
# epoch 3, minibatch 20/20, training loss 2148.947870, validation loss 2218.173421
#      epoch 3, minibatch 20/20, test accuracy of best model: source domain :75.677492 %, target domain 72.420524 %
# epoch 4, minibatch 20/20, training loss 2113.850505, validation loss 2225.377356
# epoch 5, minibatch 20/20, training loss 2049.273904, validation loss 2177.826080
#      epoch 5, minibatch 20/20, test accuracy of best model: source domain :78.230683 %, target domain 76.715003 %
# epoch 6, minibatch 20/20, training loss 2020.042806, validation loss 2176.796128
#      epoch 6, minibatch 20/20, test accuracy of best model: source domain :80.985442 %, target domain 78.555494 %
# epoch 7, minibatch 20/20, training loss 2012.503493, validation loss 2179.603871
# epoch 8, minibatch 20/20, training loss 2068.880078, validation loss 2277.014028
# epoch 9, minibatch 20/20, training loss 2041.397038, validation loss 2212.361937
# epoch 10, minibatch 20/20, training loss 2017.135548, validation loss 2230.051701
# epoch 11, minibatch 20/20, training loss 1984.446540, validation loss 2228.817251
# epoch 12, minibatch 20/20, training loss 1977.847962, validation loss 2228.987742
# epoch 13, minibatch 20/20, training loss 1975.351541, validation loss 2222.991781
# epoch 14, minibatch 20/20, training loss 1973.361631, validation loss 2232.652728
# epoch 15, minibatch 20/20, training loss 1972.461610, validation loss 2242.297464
# epoch 16, minibatch 20/20, training loss 1974.398345, validation loss 2239.369028
# epoch 17, minibatch 20/20, training loss 1972.004792, validation loss 2235.301091
# epoch 18, minibatch 20/20, training loss 1971.635777, validation loss 2232.777032
# epoch 19, minibatch 20/20, training loss 1973.889057, validation loss 2241.563946
# epoch 20, minibatch 20/20, training loss 1971.903801, validation loss 2238.414229
# epoch 21, minibatch 20/20, training loss 1972.458949, validation loss 2251.109793
# epoch 22, minibatch 20/20, training loss 1970.887196, validation loss 2244.172224
# epoch 23, minibatch 20/20, training loss 1971.254578, validation loss 2250.185096
# epoch 24, minibatch 20/20, training loss 1968.680957, validation loss 2243.465888
# epoch 25, minibatch 20/20, training loss 1967.539356, validation loss 2239.221049
# epoch 26, minibatch 20/20, training loss 1969.491164, validation loss 2236.198357
# epoch 27, minibatch 20/20, training loss 1972.052985, validation loss 2249.052800
# epoch 28, minibatch 20/20, training loss 1967.232139, validation loss 2242.820954
# epoch 29, minibatch 20/20, training loss 1965.746890, validation loss 2250.864651
# epoch 30, minibatch 20/20, training loss 1965.521634, validation loss 2238.746971
# epoch 31, minibatch 20/20, training loss 1968.458949, validation loss 2248.824201
# epoch 32, minibatch 20/20, training loss 1968.067677, validation loss 2257.224540
# epoch 33, minibatch 20/20, training loss 1966.331961, validation loss 2259.860340
# epoch 34, minibatch 20/20, training loss 1964.550493, validation loss 2251.883011
# epoch 35, minibatch 20/20, training loss 1966.963014, validation loss 2250.897564
# epoch 36, minibatch 20/20, training loss 1968.286364, validation loss 2259.609176
# epoch 37, minibatch 20/20, training loss 1963.842769, validation loss 2260.425302
# epoch 38, minibatch 20/20, training loss 1963.760065, validation loss 2259.513089
# epoch 39, minibatch 20/20, training loss 1965.322213, validation loss 2268.506085
# epoch 40, minibatch 20/20, training loss 1965.825860, validation loss 2271.449976
# epoch 41, minibatch 20/20, training loss 1966.774717, validation loss 2269.558073
# epoch 42, minibatch 20/20, training loss 1962.441941, validation loss 2262.270525
# epoch 43, minibatch 20/20, training loss 1964.276150, validation loss 2261.081226
# epoch 44, minibatch 20/20, training loss 1961.860938, validation loss 2268.742919
# epoch 45, minibatch 20/20, training loss 1963.418163, validation loss 2264.379920
# epoch 46, minibatch 20/20, training loss 1963.558899, validation loss 2270.941780
# epoch 47, minibatch 20/20, training loss 1963.810204, validation loss 2267.366506
# epoch 48, minibatch 20/20, training loss 1962.187784, validation loss 2269.364377
# epoch 49, minibatch 20/20, training loss 1964.110512, validation loss 2279.043883
# epoch 50, minibatch 20/20, training loss 1965.403667, validation loss 2284.379361
# Optimization complete. Best validation loss of 2176.796128 obtained at iteration 120, with train loss 2020.042806
# train accuracy : source domain 97.062500 %, target domain  77.875000 %
# validation accuracy : source domain 79.750000 %, target domain  77.500000 %
# test accuracy : source domain 80.985442 %, target domain  78.555494 %
# 97.06 - 79.75 - 80.99; 77.88 - 77.50 - 78.56
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.64582249992014085]
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.22366578477268503]
