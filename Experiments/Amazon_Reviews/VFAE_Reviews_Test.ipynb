# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import VFAE

import DataPackage as dp
import AmazonReviewsFeaturePlot as fp

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    max_feature=2000
    source_data, target_data = dp.datapackage(source='books', target='dvd', max_feature=max_feature, tfidf_setting='seperate')
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################          
    
    x_dim = max_feature
    y_dim = 2    
    d_dim = 2
    z_dim = 50                #dimension of latent feature
    a_dim = 50               #dimension of prior of latent feature    
    h_zy_dim = 500             #dimension of hidden unit  
    h_ay_dim = 100
    h_y_dim = 30
    learning_rate = 0.005
    activation = T.nnet.sigmoid

    struct = VFAE.VFAE_struct()    
    encoder_template = nn.NN_struct()


    struct.encoder1.share.layer_dim = [x_dim+d_dim, h_zy_dim]
    struct.encoder1.share.activation = [activation]
    struct.encoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.share.decay = [1, 1]                

    struct.encoder1.mu.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.mu.activation = [None]
    struct.encoder1.mu.learning_rate = [learning_rate]
    struct.encoder1.mu.decay = [1, 1]      
    struct.encoder1.sigma.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.sigma.activation = [None]
    struct.encoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.sigma.decay = [1, 1]   
    
    struct.encoder2.share.layer_dim = [z_dim+y_dim, h_ay_dim]
    struct.encoder2.share.activation = [activation]
    struct.encoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.share.decay = [1, 1]                
    struct.encoder2.mu.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.mu.activation = [None]
    struct.encoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.mu.decay = [1, 1]      
    struct.encoder2.sigma.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.sigma.activation = [None]
    struct.encoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.sigma.decay = [1, 1]
    
    '''
    struct.encoder3.layer_dim = [z_dim, h_y_dim, y_dim]
    struct.encoder3.activation = [activation, T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]     
    '''
    
    struct.encoder3.layer_dim = [z_dim, y_dim]
    struct.encoder3.activation = [T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]     
    
    struct.decoder1.share.layer_dim = [z_dim+d_dim, h_zy_dim]
    struct.decoder1.share.activation = [activation]
    struct.decoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.share.decay = [1, 1]                
    struct.decoder1.mu.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.mu.activation = [None]
    struct.decoder1.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.mu.decay = [1, 1]      
    struct.decoder1.sigma.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.sigma.activation = [None]
    struct.decoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.sigma.decay = [1, 1]      
    
    struct.decoder2.share.layer_dim = [a_dim+y_dim, h_ay_dim]
    struct.decoder2.share.activation = [activation]
    struct.decoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.share.decay = [1, 1]                
    struct.decoder2.mu.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.mu.activation = [None]
    struct.decoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.mu.decay = [1, 1]      
    struct.decoder2.sigma.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.sigma.activation = [None]
    struct.decoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.sigma.decay = [1, 1]      
    
    coef = VFAE.VFAE_coef(
        alpha = 1000,
        beta = 100,
        chi = 1,
        D = 500,
        L = 1,
        optimize = 'Adam_update'     
    )      
    
    
    isMMD = 'MMD_'
    if coef.beta == 0:
        isMMD = ''                
    description = 'AmazonReviews_mf%i_VFAE_%s%s' % (max_feature, isMMD, coef.optimize)
    
    features_model, test_model, trained_param = VFAE.VFAE_training(
        source_data=source_data,
        target_data=target_data,
        n_train_batches=20,
        n_epochs=50,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description)
# Out:
# number of minibatch at one epoch: 20, batch size source : 80, target : 80
#  validation size, S:400, T:400, test size, S:4465, T:3586
# ... building the model
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :49.496081 %, target domain 50.362521 %
# epoch 1, minibatch 20/20, training loss 2486.683854, validation loss 2500.284286
#      epoch 1, minibatch 20/20, test accuracy of best model: source domain :49.294513 %, target domain 49.609593 %
# epoch 2, minibatch 20/20, training loss 2271.024953, validation loss 2296.570884
#      epoch 2, minibatch 20/20, test accuracy of best model: source domain :60.873460 %, target domain 59.648634 %
# epoch 3, minibatch 20/20, training loss 2196.119303, validation loss 2233.042422
#      epoch 3, minibatch 20/20, test accuracy of best model: source domain :75.811870 %, target domain 71.360848 %
# epoch 4, minibatch 20/20, training loss 2136.999007, validation loss 2202.890713
#      epoch 4, minibatch 20/20, test accuracy of best model: source domain :78.992161 %, target domain 75.237033 %
# epoch 5, minibatch 20/20, training loss 2091.040654, validation loss 2202.471653
#      epoch 5, minibatch 20/20, test accuracy of best model: source domain :80.201568 %, target domain 78.053542 %
# epoch 6, minibatch 20/20, training loss 2058.731019, validation loss 2209.315117
# epoch 7, minibatch 20/20, training loss 2036.205434, validation loss 2239.357637
# epoch 8, minibatch 20/20, training loss 2029.278816, validation loss 2269.939438
# epoch 9, minibatch 20/20, training loss 2012.526671, validation loss 2306.307603
# epoch 10, minibatch 20/20, training loss 2006.593334, validation loss 2337.544477
# epoch 11, minibatch 20/20, training loss 2004.892610, validation loss 2373.309225
# epoch 12, minibatch 20/20, training loss 2091.098435, validation loss 2665.226921
# epoch 13, minibatch 20/20, training loss 2751.749668, validation loss 3544.713174
# epoch 14, minibatch 20/20, training loss 2091.872132, validation loss 2694.084444
# epoch 15, minibatch 20/20, training loss 2039.911499, validation loss 2509.833478
# epoch 16, minibatch 20/20, training loss 2012.095042, validation loss 2492.317319
# epoch 17, minibatch 20/20, training loss 2007.266170, validation loss 2478.397510
# epoch 18, minibatch 20/20, training loss 2003.504830, validation loss 2476.259443
# epoch 19, minibatch 20/20, training loss 2002.886626, validation loss 2514.397812
# epoch 20, minibatch 20/20, training loss 1999.629856, validation loss 2519.795187
# epoch 21, minibatch 20/20, training loss 1997.695988, validation loss 2520.348965
# epoch 22, minibatch 20/20, training loss 1995.618475, validation loss 2508.429006
# epoch 23, minibatch 20/20, training loss 1993.197954, validation loss 2544.221622
# epoch 24, minibatch 20/20, training loss 1994.033324, validation loss 2550.535035
# epoch 25, minibatch 20/20, training loss 1992.627842, validation loss 2531.348821
# epoch 26, minibatch 20/20, training loss 1992.400883, validation loss 2537.608902
# epoch 27, minibatch 20/20, training loss 1991.387323, validation loss 2513.349663
# epoch 28, minibatch 20/20, training loss 1990.062153, validation loss 2526.434031
# epoch 29, minibatch 20/20, training loss 1989.966200, validation loss 2552.759820
# epoch 30, minibatch 20/20, training loss 1989.154907, validation loss 2519.129273
# epoch 31, minibatch 20/20, training loss 1987.924527, validation loss 2557.523956
# epoch 32, minibatch 20/20, training loss 1988.498665, validation loss 2546.122745
# epoch 33, minibatch 20/20, training loss 1985.990428, validation loss 2553.819751
# epoch 34, minibatch 20/20, training loss 1987.899767, validation loss 2551.518136
# epoch 35, minibatch 20/20, training loss 1986.822757, validation loss 2559.719980
# epoch 36, minibatch 20/20, training loss 1986.834397, validation loss 2570.245819
# epoch 37, minibatch 20/20, training loss 1985.584224, validation loss 2539.554689
# epoch 38, minibatch 20/20, training loss 1985.547709, validation loss 2540.863216
# epoch 39, minibatch 20/20, training loss 1985.786090, validation loss 2558.346586
# epoch 40, minibatch 20/20, training loss 1984.888414, validation loss 2562.401197
# epoch 41, minibatch 20/20, training loss 1985.214082, validation loss 2558.164305
# epoch 42, minibatch 20/20, training loss 1986.201732, validation loss 2551.869248
# epoch 43, minibatch 20/20, training loss 1985.723991, validation loss 2576.419909
# epoch 44, minibatch 20/20, training loss 1985.016386, validation loss 2542.076503
# epoch 45, minibatch 20/20, training loss 1984.485531, validation loss 2557.330741
# epoch 46, minibatch 20/20, training loss 1983.659128, validation loss 2578.288738
# epoch 47, minibatch 20/20, training loss 1983.260292, validation loss 2571.123739
# epoch 48, minibatch 20/20, training loss 1982.140422, validation loss 2567.745436
# epoch 49, minibatch 20/20, training loss 1982.406362, validation loss 2544.330147
# epoch 50, minibatch 20/20, training loss 1982.976703, validation loss 2586.822214
# Optimization complete. Best validation loss of 2202.471653 obtained at iteration 100, with train loss 2091.040654
# train accuracy : source domain 94.937500 %, target domain  76.250000 %
# validation accuracy : source domain 80.250000 %, target domain  75.250000 %
# test accuracy : source domain 80.201568 %, target domain  78.053542 %
# 94.94 - 80.25 - 80.20; 76.25 - 75.25 - 78.05
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.43937622193838677]
