# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import DANN

import DataPackage as dp
import AmazonReviewsFeaturePlot as fp

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    max_feature=2000
    source_data, target_data = dp.datapackage(source='books', target='dvd', max_feature=max_feature, tfidf_setting='seperate')
    
    #source_data, target_data = DataDuplicate.DataDuplicate(source_data, target_data)  
    
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################          
    
    x_dim = max_feature
    y_dim = 2
    d_dim = 2
    z_dim = 50                #dimension of latent feature    
    h_dim = 500             #dimension of hidden unit      
    activation = T.nnet.sigmoid
    learning_rate = 0.005

    struct = DANN.DANN_struct()        
    struct.encoder.layer_dim = [x_dim, h_dim, z_dim]
    struct.encoder.activation = [activation, activation]
    struct.encoder.learning_rate = [learning_rate, learning_rate]
    struct.encoder.decay = [1, 1]                
    struct.classifier.layer_dim = [z_dim, y_dim]
    struct.classifier.activation = [T.nnet.softmax]   
    struct.classifier.learning_rate = [learning_rate, learning_rate]
    struct.classifier.decay = [1, 1]  
    struct.DomainClassifier.layer_dim = [z_dim, d_dim]
    struct.DomainClassifier.activation = [T.nnet.softmax]
    struct.DomainClassifier.learning_rate = [learning_rate, learning_rate]
    struct.DomainClassifier.decay = [1, 1]     
        
    coef = DANN.DANN_coef(        
        beta = 0.1,
        optimize = 'Adam_update'           
    )          
        
    description = 'AmazonReviews_mf%i_DANN_%s' % (max_feature, coef.optimize)
    
    features_model, test_model, trained_param = DANN.DANN_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 20,
        n_epochs = 100,
        k = 10,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description)
# Out:
# number of minibatch at one epoch: 20, batch size source : 80, target : 80
#  validation size, S:400, T:400, test size, S:4465, T:3586
# ... building the model
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :50.705487 %, target domain 50.390407 %
# epoch 1, minibatch 20/20, training loss 0.534297, validation loss 0.560625
#      epoch 1, minibatch 20/20, test accuracy of best model: source domain :78.409854 %, target domain 77.133296 %
# epoch 2, minibatch 20/20, training loss 0.429345, validation loss 0.492799
#      epoch 2, minibatch 20/20, test accuracy of best model: source domain :78.835386 %, target domain 74.986057 %
# epoch 3, minibatch 20/20, training loss 0.356807, validation loss 0.459656
#      epoch 3, minibatch 20/20, test accuracy of best model: source domain :78.096305 %, target domain 76.324596 %
# epoch 4, minibatch 20/20, training loss 0.272400, validation loss 0.414951
#      epoch 4, minibatch 20/20, test accuracy of best model: source domain :81.321389 %, target domain 77.997769 %
# epoch 5, minibatch 20/20, training loss 0.240009, validation loss 0.409660
#      epoch 5, minibatch 20/20, test accuracy of best model: source domain :80.537514 %, target domain 78.778583 %
# epoch 6, minibatch 20/20, training loss 0.235869, validation loss 0.421754
# epoch 7, minibatch 20/20, training loss 0.199808, validation loss 0.397343
#      epoch 7, minibatch 20/20, test accuracy of best model: source domain :80.671892 %, target domain 78.862242 %
# epoch 8, minibatch 20/20, training loss 0.156000, validation loss 0.384676
#      epoch 8, minibatch 20/20, test accuracy of best model: source domain :80.694289 %, target domain 78.973787 %
# epoch 9, minibatch 20/20, training loss 0.090245, validation loss 0.384193
#      epoch 9, minibatch 20/20, test accuracy of best model: source domain :80.604703 %, target domain 78.332404 %
# epoch 10, minibatch 20/20, training loss 0.064930, validation loss 0.397542
# epoch 11, minibatch 20/20, training loss 0.053382, validation loss 0.407230
# epoch 12, minibatch 20/20, training loss 0.044184, validation loss 0.412098
# epoch 13, minibatch 20/20, training loss 0.015351, validation loss 0.396650
# epoch 14, minibatch 20/20, training loss 0.018228, validation loss 0.433074
# epoch 15, minibatch 20/20, training loss 0.005267, validation loss 0.412701
# epoch 16, minibatch 20/20, training loss 0.011951, validation loss 0.423604
# epoch 17, minibatch 20/20, training loss 0.003960, validation loss 0.433089
# epoch 18, minibatch 20/20, training loss 0.007903, validation loss 0.430850
# epoch 19, minibatch 20/20, training loss 0.004155, validation loss 0.428565
# epoch 20, minibatch 20/20, training loss -0.005905, validation loss 0.435023
# epoch 21, minibatch 20/20, training loss -0.008609, validation loss 0.441257
# epoch 22, minibatch 20/20, training loss -0.002577, validation loss 0.445146
# epoch 23, minibatch 20/20, training loss 0.000603, validation loss 0.432354
# epoch 24, minibatch 20/20, training loss 0.001910, validation loss 0.429152
# epoch 25, minibatch 20/20, training loss -0.012072, validation loss 0.438168
# epoch 26, minibatch 20/20, training loss -0.010215, validation loss 0.431475
# epoch 27, minibatch 20/20, training loss -0.011137, validation loss 0.422278
# epoch 28, minibatch 20/20, training loss -0.015933, validation loss 0.437736
# epoch 29, minibatch 20/20, training loss -0.008744, validation loss 0.440823
# epoch 30, minibatch 20/20, training loss -0.023793, validation loss 0.453160
# epoch 31, minibatch 20/20, training loss -0.018869, validation loss 0.466151
# epoch 32, minibatch 20/20, training loss -0.021473, validation loss 0.470250
# epoch 33, minibatch 20/20, training loss -0.020750, validation loss 0.451628
# epoch 34, minibatch 20/20, training loss -0.017346, validation loss 0.470125
# epoch 35, minibatch 20/20, training loss -0.034377, validation loss 0.473585
# epoch 36, minibatch 20/20, training loss -0.026742, validation loss 0.470286
# epoch 37, minibatch 20/20, training loss -0.016910, validation loss 0.448886
# epoch 38, minibatch 20/20, training loss -0.025502, validation loss 0.450789
# epoch 39, minibatch 20/20, training loss -0.019551, validation loss 0.475729
# epoch 40, minibatch 20/20, training loss -0.017912, validation loss 0.460857
# epoch 41, minibatch 20/20, training loss -0.022241, validation loss 0.450449
# epoch 42, minibatch 20/20, training loss -0.025309, validation loss 0.465799
# epoch 43, minibatch 20/20, training loss -0.017743, validation loss 0.444584
# epoch 44, minibatch 20/20, training loss -0.027070, validation loss 0.483182
# epoch 45, minibatch 20/20, training loss -0.017612, validation loss 0.445100
# epoch 46, minibatch 20/20, training loss -0.033423, validation loss 0.437364
# epoch 47, minibatch 20/20, training loss -0.023571, validation loss 0.475104
# epoch 48, minibatch 20/20, training loss -0.016671, validation loss 0.456072
# epoch 49, minibatch 20/20, training loss -0.027734, validation loss 0.467117
# epoch 50, minibatch 20/20, training loss -0.032451, validation loss 0.464941
# epoch 51, minibatch 20/20, training loss -0.022329, validation loss 0.468082
# epoch 52, minibatch 20/20, training loss -0.026343, validation loss 0.486899
# epoch 53, minibatch 20/20, training loss -0.028904, validation loss 0.465094
# epoch 54, minibatch 20/20, training loss -0.022912, validation loss 0.465576
# epoch 55, minibatch 20/20, training loss -0.031163, validation loss 0.453236
# epoch 56, minibatch 20/20, training loss -0.016755, validation loss 0.469713
# epoch 57, minibatch 20/20, training loss -0.021479, validation loss 0.464871
# epoch 58, minibatch 20/20, training loss -0.023564, validation loss 0.470548
# epoch 59, minibatch 20/20, training loss -0.040559, validation loss 0.470169
# epoch 60, minibatch 20/20, training loss -0.020147, validation loss 0.445964
# epoch 61, minibatch 20/20, training loss -0.035504, validation loss 0.464863
# epoch 62, minibatch 20/20, training loss -0.016384, validation loss 0.448750
# epoch 63, minibatch 20/20, training loss -0.026250, validation loss 0.478253
# epoch 64, minibatch 20/20, training loss -0.029235, validation loss 0.449080
# epoch 65, minibatch 20/20, training loss -0.025243, validation loss 0.479311
# epoch 66, minibatch 20/20, training loss -0.039046, validation loss 0.462034
# epoch 67, minibatch 20/20, training loss -0.026124, validation loss 0.462113
# epoch 68, minibatch 20/20, training loss -0.029633, validation loss 0.465850
# epoch 69, minibatch 20/20, training loss -0.022384, validation loss 0.482538
# epoch 70, minibatch 20/20, training loss -0.033423, validation loss 0.483562
# epoch 71, minibatch 20/20, training loss -0.018063, validation loss 0.454970
# epoch 72, minibatch 20/20, training loss -0.023172, validation loss 0.480018
# epoch 73, minibatch 20/20, training loss -0.029500, validation loss 0.498618
# epoch 74, minibatch 20/20, training loss -0.027412, validation loss 0.464429
# epoch 75, minibatch 20/20, training loss -0.020264, validation loss 0.464246
# epoch 76, minibatch 20/20, training loss -0.025907, validation loss 0.476533
# epoch 77, minibatch 20/20, training loss -0.027727, validation loss 0.476561
# epoch 78, minibatch 20/20, training loss -0.035126, validation loss 0.463007
# epoch 79, minibatch 20/20, training loss -0.021612, validation loss 0.496538
# epoch 80, minibatch 20/20, training loss -0.023223, validation loss 0.491628
# epoch 81, minibatch 20/20, training loss -0.035285, validation loss 0.509377
# epoch 82, minibatch 20/20, training loss -0.035259, validation loss 0.503952
# epoch 83, minibatch 20/20, training loss -0.036313, validation loss 0.534236
# epoch 84, minibatch 20/20, training loss -0.033348, validation loss 0.503101
# epoch 85, minibatch 20/20, training loss -0.033365, validation loss 0.500461
# epoch 86, minibatch 20/20, training loss -0.030469, validation loss 0.518182
# epoch 87, minibatch 20/20, training loss -0.032638, validation loss 0.529762
# epoch 88, minibatch 20/20, training loss -0.034291, validation loss 0.502420
# epoch 89, minibatch 20/20, training loss -0.030457, validation loss 0.509159
# epoch 90, minibatch 20/20, training loss -0.035337, validation loss 0.547570
# epoch 91, minibatch 20/20, training loss -0.033001, validation loss 0.512133
# epoch 92, minibatch 20/20, training loss -0.030632, validation loss 0.488848
# epoch 93, minibatch 20/20, training loss -0.030493, validation loss 0.488177
# epoch 94, minibatch 20/20, training loss -0.035553, validation loss 0.507543
# epoch 95, minibatch 20/20, training loss -0.033296, validation loss 0.563315
# epoch 96, minibatch 20/20, training loss -0.046572, validation loss 0.540689
# epoch 97, minibatch 20/20, training loss -0.032380, validation loss 0.513001
# epoch 98, minibatch 20/20, training loss -0.030972, validation loss 0.517546
# epoch 99, minibatch 20/20, training loss -0.036591, validation loss 0.559598
# epoch 100, minibatch 20/20, training loss -0.040639, validation loss 0.585759
# Optimization complete. Best validation loss of 0.384193 obtained at iteration 180, with train loss 0.090245
# train accuracy : source domain 99.437500 %, target domain  77.125000 %
# validation accuracy : source domain 81.250000 %, target domain  79.500000 %
# test accuracy : source domain 80.604703 %, target domain  78.332404 %
# 99.44 - 81.25 - 80.60; 77.12 - 79.50 - 78.33
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.15852231666539854]
