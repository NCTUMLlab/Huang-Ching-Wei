# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle


import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

#add the path of Folder Model
sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import DSSL

import TwinMoonFeaturePlot as fp
# Out:
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: invalid argument)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    file = '/home/cwhuang/DVTL/Dataset/Synthetic_Data/Twin_moon.npy'
    data = np.load(file)
    
    train_fts_source, train_labels_source = data[0]
    valid_fts_source, valid_labels_source = data[1]
    test_fts_source, test_labels_source = data[2]
    
    train_fts_target, train_labels_target = data[3]
    valid_fts_target, valid_labels_target = data[4]
    test_fts_target, test_labels_target = data[5]
    
    source_data = [(train_fts_source, train_labels_source), (valid_fts_source, valid_labels_source), (test_fts_source, test_labels_source)]
    target_data = [(train_fts_target, train_labels_target), (valid_fts_target, valid_labels_target), (test_fts_target, test_labels_target)] 
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################           

    x_dim = 2
    y_dim = 2
    z_dim = 5                #dimension of latent feature    
    h_dim = 10             #dimension of hidden unit      
    activation = T.nnet.sigmoid
    lr = 0.05

    struct = DSSL.DSSL_struct()        
    struct.encoder.layer_dim = [x_dim, h_dim, z_dim]
    struct.encoder.activation = [activation, activation]
    struct.encoder.learning_rate = [lr, lr]
    struct.encoder.decay = [1, 1]                
    struct.classifier.layer_dim = [z_dim, y_dim]
    struct.classifier.activation = [T.nnet.softmax]   
    struct.classifier.learning_rate = [lr, lr]
    struct.classifier.decay = [1, 1]
    struct.decoder.layer_dim = [z_dim, h_dim, x_dim]
    struct.decoder.activation = [activation, activation ]   
    struct.decoder.learning_rate = [lr, lr]
    struct.decoder.decay = [1, 1]    
        
    coef = DSSL.DSSL_coef(    
        alpha = 1,
        beta = 1,
        D = 100,
        optimize = 'Adam_update'        
    )         
        
    isMMD = 'MMD_'
    if coef.beta == 0:
        isMMD = ''        
        
    description = 'TwinMoon_DSSL_%s%s' % (isMMD, coef.optimize)
        
    features_model, test_model, trained_param = DSSL.DSSL_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 10,
        n_epochs=200,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description)
# Out:
# number of minibatch at one epoch: 10, batch size source : 100, target : 100
#  validation size, S:600, T:600, test size, S:400, T:400
# ... building the model
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# ... training
# Initial, test accuracy: source domain :50.000000 %, target domain 50.000000 %
# epoch 1, minibatch 10/10, training loss 1.705450, validation loss 1.707760
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :50.000000 %, target domain 50.000000 %
# epoch 2, minibatch 10/10, training loss 1.553601, validation loss 1.544934
#      epoch 2, minibatch 10/10, test accuracy of best model: source domain :76.750000 %, target domain 74.750000 %
# epoch 3, minibatch 10/10, training loss 1.422107, validation loss 1.419097
#      epoch 3, minibatch 10/10, test accuracy of best model: source domain :77.250000 %, target domain 84.750000 %
# epoch 4, minibatch 10/10, training loss 1.361063, validation loss 1.367614
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :79.500000 %, target domain 85.000000 %
# epoch 5, minibatch 10/10, training loss 1.336825, validation loss 1.341219
#      epoch 5, minibatch 10/10, test accuracy of best model: source domain :80.500000 %, target domain 86.750000 %
# epoch 6, minibatch 10/10, training loss 1.321686, validation loss 1.325668
#      epoch 6, minibatch 10/10, test accuracy of best model: source domain :80.500000 %, target domain 87.500000 %
# epoch 7, minibatch 10/10, training loss 1.307654, validation loss 1.312478
#      epoch 7, minibatch 10/10, test accuracy of best model: source domain :81.250000 %, target domain 87.250000 %
# epoch 8, minibatch 10/10, training loss 1.289509, validation loss 1.292252
#      epoch 8, minibatch 10/10, test accuracy of best model: source domain :81.750000 %, target domain 87.000000 %
# epoch 9, minibatch 10/10, training loss 1.265951, validation loss 1.266601
#      epoch 9, minibatch 10/10, test accuracy of best model: source domain :83.250000 %, target domain 86.250000 %
# epoch 10, minibatch 10/10, training loss 1.242934, validation loss 1.243717
#      epoch 10, minibatch 10/10, test accuracy of best model: source domain :86.000000 %, target domain 85.000000 %
# epoch 11, minibatch 10/10, training loss 1.220016, validation loss 1.224096
#      epoch 11, minibatch 10/10, test accuracy of best model: source domain :88.500000 %, target domain 84.000000 %
# epoch 12, minibatch 10/10, training loss 1.197214, validation loss 1.205061
#      epoch 12, minibatch 10/10, test accuracy of best model: source domain :90.750000 %, target domain 84.500000 %
# epoch 13, minibatch 10/10, training loss 1.172966, validation loss 1.184458
#      epoch 13, minibatch 10/10, test accuracy of best model: source domain :92.750000 %, target domain 84.000000 %
# epoch 14, minibatch 10/10, training loss 1.146623, validation loss 1.163375
#      epoch 14, minibatch 10/10, test accuracy of best model: source domain :95.000000 %, target domain 84.750000 %
# epoch 15, minibatch 10/10, training loss 1.120255, validation loss 1.141471
#      epoch 15, minibatch 10/10, test accuracy of best model: source domain :96.500000 %, target domain 86.500000 %
# epoch 16, minibatch 10/10, training loss 1.096073, validation loss 1.118252
#      epoch 16, minibatch 10/10, test accuracy of best model: source domain :97.500000 %, target domain 87.750000 %
# epoch 17, minibatch 10/10, training loss 1.074472, validation loss 1.097099
#      epoch 17, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 89.000000 %
# epoch 18, minibatch 10/10, training loss 1.055142, validation loss 1.081150
#      epoch 18, minibatch 10/10, test accuracy of best model: source domain :98.750000 %, target domain 90.500000 %
# epoch 19, minibatch 10/10, training loss 1.038589, validation loss 1.067303
#      epoch 19, minibatch 10/10, test accuracy of best model: source domain :99.500000 %, target domain 92.250000 %
# epoch 20, minibatch 10/10, training loss 1.025093, validation loss 1.056167
#      epoch 20, minibatch 10/10, test accuracy of best model: source domain :99.500000 %, target domain 93.000000 %
# epoch 21, minibatch 10/10, training loss 1.014250, validation loss 1.047148
#      epoch 21, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 93.500000 %
# epoch 22, minibatch 10/10, training loss 1.005491, validation loss 1.040139
#      epoch 22, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 93.750000 %
# epoch 23, minibatch 10/10, training loss 0.998336, validation loss 1.034844
#      epoch 23, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 24, minibatch 10/10, training loss 0.992423, validation loss 1.030642
#      epoch 24, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.500000 %
# epoch 25, minibatch 10/10, training loss 0.987478, validation loss 1.027349
#      epoch 25, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.500000 %
# epoch 26, minibatch 10/10, training loss 0.983295, validation loss 1.024694
#      epoch 26, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 27, minibatch 10/10, training loss 0.979710, validation loss 1.022468
#      epoch 27, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 28, minibatch 10/10, training loss 0.976599, validation loss 1.020574
#      epoch 28, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 29, minibatch 10/10, training loss 0.973872, validation loss 1.018928
#      epoch 29, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 30, minibatch 10/10, training loss 0.971454, validation loss 1.017471
#      epoch 30, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 31, minibatch 10/10, training loss 0.969293, validation loss 1.016169
#      epoch 31, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 32, minibatch 10/10, training loss 0.967344, validation loss 1.014989
#      epoch 32, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 33, minibatch 10/10, training loss 0.965572, validation loss 1.013906
#      epoch 33, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 34, minibatch 10/10, training loss 0.963951, validation loss 1.012899
#      epoch 34, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 35, minibatch 10/10, training loss 0.962458, validation loss 1.011951
#      epoch 35, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 36, minibatch 10/10, training loss 0.961072, validation loss 1.011048
#      epoch 36, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 37, minibatch 10/10, training loss 0.959778, validation loss 1.010177
#      epoch 37, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 38, minibatch 10/10, training loss 0.958561, validation loss 1.009327
#      epoch 38, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 39, minibatch 10/10, training loss 0.957410, validation loss 1.008488
#      epoch 39, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 40, minibatch 10/10, training loss 0.956312, validation loss 1.007649
#      epoch 40, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 41, minibatch 10/10, training loss 0.955259, validation loss 1.006801
#      epoch 41, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 42, minibatch 10/10, training loss 0.954241, validation loss 1.005931
#      epoch 42, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 43, minibatch 10/10, training loss 0.953248, validation loss 1.005031
#      epoch 43, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 44, minibatch 10/10, training loss 0.952274, validation loss 1.004088
#      epoch 44, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 45, minibatch 10/10, training loss 0.951309, validation loss 1.003090
#      epoch 45, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 46, minibatch 10/10, training loss 0.950346, validation loss 1.002027
#      epoch 46, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 47, minibatch 10/10, training loss 0.949378, validation loss 1.000886
#      epoch 47, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 48, minibatch 10/10, training loss 0.948397, validation loss 0.999656
#      epoch 48, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 49, minibatch 10/10, training loss 0.947395, validation loss 0.998327
#      epoch 49, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 50, minibatch 10/10, training loss 0.946364, validation loss 0.996890
#      epoch 50, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 51, minibatch 10/10, training loss 0.945293, validation loss 0.995331
#      epoch 51, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 52, minibatch 10/10, training loss 0.944168, validation loss 0.993632
#      epoch 52, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 53, minibatch 10/10, training loss 0.942974, validation loss 0.991765
#      epoch 53, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 54, minibatch 10/10, training loss 0.941698, validation loss 0.989700
#      epoch 54, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 55, minibatch 10/10, training loss 0.940339, validation loss 0.987419
#      epoch 55, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 56, minibatch 10/10, training loss 0.938924, validation loss 0.984951
#      epoch 56, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 57, minibatch 10/10, training loss 0.937511, validation loss 0.982386
#      epoch 57, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 58, minibatch 10/10, training loss 0.936164, validation loss 0.979849
#      epoch 58, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 59, minibatch 10/10, training loss 0.934927, validation loss 0.977452
#      epoch 59, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 60, minibatch 10/10, training loss 0.933804, validation loss 0.975258
#      epoch 60, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 61, minibatch 10/10, training loss 0.932783, validation loss 0.973292
#      epoch 61, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.250000 %
# epoch 62, minibatch 10/10, training loss 0.931847, validation loss 0.971546
#      epoch 62, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 63, minibatch 10/10, training loss 0.930985, validation loss 0.969990
#      epoch 63, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 64, minibatch 10/10, training loss 0.930187, validation loss 0.968586
#      epoch 64, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 99.000000 %
# epoch 65, minibatch 10/10, training loss 0.929445, validation loss 0.967299
#      epoch 65, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.750000 %
# epoch 66, minibatch 10/10, training loss 0.928752, validation loss 0.966104
#      epoch 66, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 67, minibatch 10/10, training loss 0.928102, validation loss 0.964988
#      epoch 67, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 68, minibatch 10/10, training loss 0.927490, validation loss 0.963941
#      epoch 68, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.500000 %
# epoch 69, minibatch 10/10, training loss 0.926912, validation loss 0.962957
#      epoch 69, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 70, minibatch 10/10, training loss 0.926364, validation loss 0.962032
#      epoch 70, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 71, minibatch 10/10, training loss 0.925844, validation loss 0.961159
#      epoch 71, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.250000 %
# epoch 72, minibatch 10/10, training loss 0.925348, validation loss 0.960332
#      epoch 72, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 73, minibatch 10/10, training loss 0.924875, validation loss 0.959548
#      epoch 73, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 74, minibatch 10/10, training loss 0.924422, validation loss 0.958801
#      epoch 74, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 75, minibatch 10/10, training loss 0.923987, validation loss 0.958089
#      epoch 75, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 76, minibatch 10/10, training loss 0.923569, validation loss 0.957408
#      epoch 76, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 77, minibatch 10/10, training loss 0.923167, validation loss 0.956756
#      epoch 77, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 78, minibatch 10/10, training loss 0.922779, validation loss 0.956128
#      epoch 78, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 79, minibatch 10/10, training loss 0.922403, validation loss 0.955524
#      epoch 79, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 80, minibatch 10/10, training loss 0.922039, validation loss 0.954940
#      epoch 80, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 81, minibatch 10/10, training loss 0.921686, validation loss 0.954376
#      epoch 81, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 82, minibatch 10/10, training loss 0.921343, validation loss 0.953828
#      epoch 82, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 83, minibatch 10/10, training loss 0.921010, validation loss 0.953296
#      epoch 83, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 84, minibatch 10/10, training loss 0.920685, validation loss 0.952778
#      epoch 84, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 85, minibatch 10/10, training loss 0.920368, validation loss 0.952274
#      epoch 85, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 86, minibatch 10/10, training loss 0.920058, validation loss 0.951782
#      epoch 86, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 87, minibatch 10/10, training loss 0.919756, validation loss 0.951302
#      epoch 87, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 88, minibatch 10/10, training loss 0.919460, validation loss 0.950832
#      epoch 88, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 89, minibatch 10/10, training loss 0.919170, validation loss 0.950372
#      epoch 89, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 90, minibatch 10/10, training loss 0.918886, validation loss 0.949922
#      epoch 90, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 91, minibatch 10/10, training loss 0.918608, validation loss 0.949481
#      epoch 91, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 92, minibatch 10/10, training loss 0.918335, validation loss 0.949048
#      epoch 92, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 93, minibatch 10/10, training loss 0.918067, validation loss 0.948623
#      epoch 93, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 94, minibatch 10/10, training loss 0.917803, validation loss 0.948206
#      epoch 94, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 95, minibatch 10/10, training loss 0.917544, validation loss 0.947796
#      epoch 95, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 96, minibatch 10/10, training loss 0.917289, validation loss 0.947393
#      epoch 96, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 97, minibatch 10/10, training loss 0.917038, validation loss 0.946995
#      epoch 97, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 98, minibatch 10/10, training loss 0.916790, validation loss 0.946603
#      epoch 98, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 99, minibatch 10/10, training loss 0.916547, validation loss 0.946216
#      epoch 99, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 100, minibatch 10/10, training loss 0.916306, validation loss 0.945833
#      epoch 100, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 101, minibatch 10/10, training loss 0.916069, validation loss 0.945454
#      epoch 101, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 102, minibatch 10/10, training loss 0.915834, validation loss 0.945080
#      epoch 102, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 103, minibatch 10/10, training loss 0.915603, validation loss 0.944709
#      epoch 103, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 104, minibatch 10/10, training loss 0.915375, validation loss 0.944342
#      epoch 104, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 105, minibatch 10/10, training loss 0.915149, validation loss 0.943978
#      epoch 105, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 106, minibatch 10/10, training loss 0.914926, validation loss 0.943618
#      epoch 106, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 107, minibatch 10/10, training loss 0.914705, validation loss 0.943260
#      epoch 107, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 108, minibatch 10/10, training loss 0.914487, validation loss 0.942906
#      epoch 108, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 109, minibatch 10/10, training loss 0.914271, validation loss 0.942555
#      epoch 109, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 110, minibatch 10/10, training loss 0.914058, validation loss 0.942206
#      epoch 110, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 111, minibatch 10/10, training loss 0.913847, validation loss 0.941859
#      epoch 111, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 112, minibatch 10/10, training loss 0.913638, validation loss 0.941516
#      epoch 112, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 113, minibatch 10/10, training loss 0.913431, validation loss 0.941174
#      epoch 113, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 114, minibatch 10/10, training loss 0.913227, validation loss 0.940835
#      epoch 114, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 115, minibatch 10/10, training loss 0.913025, validation loss 0.940499
#      epoch 115, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 116, minibatch 10/10, training loss 0.912825, validation loss 0.940164
#      epoch 116, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 117, minibatch 10/10, training loss 0.912628, validation loss 0.939832
#      epoch 117, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 118, minibatch 10/10, training loss 0.912432, validation loss 0.939502
#      epoch 118, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 119, minibatch 10/10, training loss 0.912239, validation loss 0.939174
#      epoch 119, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 120, minibatch 10/10, training loss 0.912048, validation loss 0.938848
#      epoch 120, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 121, minibatch 10/10, training loss 0.911859, validation loss 0.938524
#      epoch 121, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 122, minibatch 10/10, training loss 0.911673, validation loss 0.938203
#      epoch 122, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.250000 %
# epoch 123, minibatch 10/10, training loss 0.911489, validation loss 0.937883
#      epoch 123, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 124, minibatch 10/10, training loss 0.911307, validation loss 0.937566
#      epoch 124, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 125, minibatch 10/10, training loss 0.911127, validation loss 0.937251
#      epoch 125, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 126, minibatch 10/10, training loss 0.910950, validation loss 0.936938
#      epoch 126, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 127, minibatch 10/10, training loss 0.910776, validation loss 0.936627
#      epoch 127, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 128, minibatch 10/10, training loss 0.910603, validation loss 0.936319
#      epoch 128, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 129, minibatch 10/10, training loss 0.910433, validation loss 0.936013
#      epoch 129, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 130, minibatch 10/10, training loss 0.910266, validation loss 0.935709
#      epoch 130, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 131, minibatch 10/10, training loss 0.910101, validation loss 0.935408
#      epoch 131, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 132, minibatch 10/10, training loss 0.909938, validation loss 0.935110
#      epoch 132, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 133, minibatch 10/10, training loss 0.909778, validation loss 0.934814
#      epoch 133, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.500000 %
# epoch 134, minibatch 10/10, training loss 0.909621, validation loss 0.934521
#      epoch 134, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 135, minibatch 10/10, training loss 0.909465, validation loss 0.934231
#      epoch 135, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 136, minibatch 10/10, training loss 0.909313, validation loss 0.933944
#      epoch 136, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 137, minibatch 10/10, training loss 0.909163, validation loss 0.933660
#      epoch 137, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 138, minibatch 10/10, training loss 0.909015, validation loss 0.933379
#      epoch 138, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 139, minibatch 10/10, training loss 0.908870, validation loss 0.933101
#      epoch 139, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 140, minibatch 10/10, training loss 0.908727, validation loss 0.932827
#      epoch 140, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 141, minibatch 10/10, training loss 0.908586, validation loss 0.932557
#      epoch 141, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 142, minibatch 10/10, training loss 0.908448, validation loss 0.932289
#      epoch 142, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 143, minibatch 10/10, training loss 0.908312, validation loss 0.932026
#      epoch 143, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 144, minibatch 10/10, training loss 0.908179, validation loss 0.931766
#      epoch 144, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 145, minibatch 10/10, training loss 0.908048, validation loss 0.931511
#      epoch 145, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 146, minibatch 10/10, training loss 0.907919, validation loss 0.931259
#      epoch 146, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 147, minibatch 10/10, training loss 0.907792, validation loss 0.931011
#      epoch 147, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 148, minibatch 10/10, training loss 0.907668, validation loss 0.930767
#      epoch 148, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 149, minibatch 10/10, training loss 0.907545, validation loss 0.930526
#      epoch 149, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 150, minibatch 10/10, training loss 0.907425, validation loss 0.930290
#      epoch 150, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 151, minibatch 10/10, training loss 0.907307, validation loss 0.930058
#      epoch 151, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 152, minibatch 10/10, training loss 0.907191, validation loss 0.929830
#      epoch 152, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 153, minibatch 10/10, training loss 0.907076, validation loss 0.929605
#      epoch 153, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 154, minibatch 10/10, training loss 0.906964, validation loss 0.929385
#      epoch 154, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 155, minibatch 10/10, training loss 0.906854, validation loss 0.929168
#      epoch 155, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 156, minibatch 10/10, training loss 0.906745, validation loss 0.928955
#      epoch 156, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 157, minibatch 10/10, training loss 0.906638, validation loss 0.928746
#      epoch 157, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 158, minibatch 10/10, training loss 0.906533, validation loss 0.928540
#      epoch 158, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 159, minibatch 10/10, training loss 0.906430, validation loss 0.928338
#      epoch 159, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 160, minibatch 10/10, training loss 0.906329, validation loss 0.928140
#      epoch 160, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 161, minibatch 10/10, training loss 0.906229, validation loss 0.927944
#      epoch 161, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 162, minibatch 10/10, training loss 0.906130, validation loss 0.927752
#      epoch 162, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 163, minibatch 10/10, training loss 0.906033, validation loss 0.927564
#      epoch 163, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 164, minibatch 10/10, training loss 0.905938, validation loss 0.927378
#      epoch 164, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 165, minibatch 10/10, training loss 0.905844, validation loss 0.927195
#      epoch 165, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 166, minibatch 10/10, training loss 0.905752, validation loss 0.927016
#      epoch 166, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 167, minibatch 10/10, training loss 0.905661, validation loss 0.926839
#      epoch 167, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 168, minibatch 10/10, training loss 0.905571, validation loss 0.926664
#      epoch 168, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 169, minibatch 10/10, training loss 0.905483, validation loss 0.926493
#      epoch 169, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 170, minibatch 10/10, training loss 0.905396, validation loss 0.926324
#      epoch 170, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 171, minibatch 10/10, training loss 0.905310, validation loss 0.926157
#      epoch 171, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 172, minibatch 10/10, training loss 0.905225, validation loss 0.925993
#      epoch 172, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 173, minibatch 10/10, training loss 0.905142, validation loss 0.925832
#      epoch 173, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 174, minibatch 10/10, training loss 0.905059, validation loss 0.925672
#      epoch 174, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 175, minibatch 10/10, training loss 0.904978, validation loss 0.925515
#      epoch 175, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 176, minibatch 10/10, training loss 0.904898, validation loss 0.925359
#      epoch 176, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 177, minibatch 10/10, training loss 0.904819, validation loss 0.925206
#      epoch 177, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 178, minibatch 10/10, training loss 0.904741, validation loss 0.925055
#      epoch 178, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 179, minibatch 10/10, training loss 0.904664, validation loss 0.924906
#      epoch 179, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 180, minibatch 10/10, training loss 0.904588, validation loss 0.924758
#      epoch 180, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 181, minibatch 10/10, training loss 0.904512, validation loss 0.924613
#      epoch 181, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 182, minibatch 10/10, training loss 0.904438, validation loss 0.924469
#      epoch 182, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 183, minibatch 10/10, training loss 0.904365, validation loss 0.924327
#      epoch 183, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 184, minibatch 10/10, training loss 0.904292, validation loss 0.924187
#      epoch 184, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 185, minibatch 10/10, training loss 0.904220, validation loss 0.924048
#      epoch 185, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 186, minibatch 10/10, training loss 0.904149, validation loss 0.923911
#      epoch 186, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 187, minibatch 10/10, training loss 0.904079, validation loss 0.923775
#      epoch 187, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 188, minibatch 10/10, training loss 0.904010, validation loss 0.923641
#      epoch 188, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 189, minibatch 10/10, training loss 0.903941, validation loss 0.923509
#      epoch 189, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 190, minibatch 10/10, training loss 0.903873, validation loss 0.923378
#      epoch 190, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 191, minibatch 10/10, training loss 0.903806, validation loss 0.923248
#      epoch 191, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 192, minibatch 10/10, training loss 0.903739, validation loss 0.923120
#      epoch 192, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 193, minibatch 10/10, training loss 0.903673, validation loss 0.922993
#      epoch 193, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 194, minibatch 10/10, training loss 0.903608, validation loss 0.922867
#      epoch 194, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 195, minibatch 10/10, training loss 0.903543, validation loss 0.922743
#      epoch 195, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 98.000000 %
# epoch 196, minibatch 10/10, training loss 0.903479, validation loss 0.922620
#      epoch 196, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 197, minibatch 10/10, training loss 0.903415, validation loss 0.922498
#      epoch 197, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 198, minibatch 10/10, training loss 0.903352, validation loss 0.922377
#      epoch 198, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 199, minibatch 10/10, training loss 0.903290, validation loss 0.922258
#      epoch 199, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# epoch 200, minibatch 10/10, training loss 0.903228, validation loss 0.922139
#      epoch 200, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.750000 %
# Optimization complete. Best validation loss of 0.922139 obtained at iteration 2000, with train loss 0.903228
# train accuracy : source domain 100.000000 %, target domain  97.400000 %
# validation accuracy : source domain 100.000000 %, target domain  98.166667 %
# test accuracy : source domain 100.000000 %, target domain  97.750000 %
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.036793170788780312]
# -------------------------------------------------------------------------
