# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

#add the path of Folder Model
sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import VLDF_ANN

import TwinMoonFeaturePlot as fp
# Out:
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: invalid argument)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    file = '/home/cwhuang/DVTL/Dataset/Synthetic_Data/Twin_moon.npy'
    data = np.load(file)
    
    train_fts_source, train_labels_source = data[0]
    valid_fts_source, valid_labels_source = data[1]
    test_fts_source, test_labels_source = data[2]
    
    train_fts_target, train_labels_target = data[3]
    valid_fts_target, valid_labels_target = data[4]
    test_fts_target, test_labels_target = data[5]
    
    source_data = [(train_fts_source, train_labels_source), (valid_fts_source, valid_labels_source), (test_fts_source, test_labels_source)]
    target_data = [(train_fts_target, train_labels_target), (valid_fts_target, valid_labels_target), (test_fts_target, test_labels_target)]   
    
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################           

    x_dim = 2
    y_dim = 2    
    d_dim = 2    
    z_dim = 5                #dimension of latent feature
    a_dim = 5               #dimension of prior of latent feature    
    h_z_dim = 10             #dimension of hidden unit  
    h_a_dim = 5
    h_y_dim = 5
    learning_rate = 0.01
    activation = T.nnet.sigmoid

    
    struct = VLDF_ANN.VLDF_ANN_struct()    
    encoder_template = nn.NN_struct()
    
    struct.encoder1.share.layer_dim = [x_dim+d_dim, h_z_dim]
    struct.encoder1.share.activation = [activation]
    struct.encoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.share.decay = [1, 1]                
    struct.encoder1.mu.layer_dim = [h_z_dim, z_dim]
    struct.encoder1.mu.activation = [None]
    struct.encoder1.mu.learning_rate = [learning_rate]
    struct.encoder1.mu.decay = [1]      
    struct.encoder1.sigma.layer_dim = [h_z_dim, z_dim]
    struct.encoder1.sigma.activation = [None]
    struct.encoder1.sigma.learning_rate = [learning_rate]
    struct.encoder1.sigma.decay = [1]   

    struct.encoder2.share.layer_dim = [x_dim+d_dim, h_z_dim]
    struct.encoder2.share.activation = [activation]
    struct.encoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.share.decay = [1, 1]                
    struct.encoder2.mu.layer_dim = [h_z_dim, z_dim]
    struct.encoder2.mu.activation = [None]
    struct.encoder2.mu.learning_rate = [learning_rate]
    struct.encoder2.mu.decay = [1]      
    struct.encoder2.sigma.layer_dim = [h_z_dim, z_dim]
    struct.encoder2.sigma.activation = [None]
    struct.encoder2.sigma.learning_rate = [learning_rate]
    struct.encoder2.sigma.decay = [1]     
    
    struct.encoder3.share.layer_dim = [z_dim+y_dim, h_a_dim]
    struct.encoder3.share.activation = [activation]
    struct.encoder3.share.learning_rate = [learning_rate]
    struct.encoder3.share.decay = [1]                
    struct.encoder3.mu.layer_dim = [h_a_dim, a_dim]
    struct.encoder3.mu.activation = [None]
    struct.encoder3.mu.learning_rate = [learning_rate]
    struct.encoder3.mu.decay = [1]      
    struct.encoder3.sigma.layer_dim = [h_a_dim, a_dim]
    struct.encoder3.sigma.activation = [None]
    struct.encoder3.sigma.learning_rate = [learning_rate]
    struct.encoder3.sigma.decay = [1]

    struct.encoder4.share.layer_dim = [z_dim+d_dim, h_a_dim]
    struct.encoder4.share.activation = [activation]
    struct.encoder4.share.learning_rate = [learning_rate]
    struct.encoder4.share.decay = [1]                
    struct.encoder4.mu.layer_dim = [h_a_dim, a_dim]
    struct.encoder4.mu.activation = [None]
    struct.encoder4.mu.learning_rate = [learning_rate]
    struct.encoder4.mu.decay = [1]      
    struct.encoder4.sigma.layer_dim = [h_a_dim, a_dim]
    struct.encoder4.sigma.activation = [None]
    struct.encoder4.sigma.learning_rate = [learning_rate]
    struct.encoder4.sigma.decay = [1]    
    
    struct.encoder5.layer_dim = [z_dim, h_y_dim, y_dim]
    struct.encoder5.activation = [activation, T.nnet.softmax]   
    struct.encoder5.learning_rate = [learning_rate, learning_rate]
    struct.encoder5.decay = [1, 1]     

    struct.decoder1.share.layer_dim = [z_dim+z_dim, h_z_dim]
    struct.decoder1.share.activation = [activation]
    struct.decoder1.share.learning_rate = [learning_rate]
    struct.decoder1.share.decay = [1]                
    struct.decoder1.mu.layer_dim = [h_z_dim, x_dim]
    struct.decoder1.mu.activation = [None]
    struct.decoder1.mu.learning_rate = [learning_rate]
    struct.decoder1.mu.decay = [1]      
    struct.decoder1.sigma.layer_dim = [h_z_dim, x_dim]
    struct.decoder1.sigma.activation = [None]
    struct.decoder1.sigma.learning_rate = [learning_rate]
    struct.decoder1.sigma.decay = [1]      
    
    struct.decoder2.share.layer_dim = [a_dim+y_dim, h_a_dim]
    struct.decoder2.share.activation = [activation]
    struct.decoder2.share.learning_rate = [learning_rate]
    struct.decoder2.share.decay = [1]                
    struct.decoder2.mu.layer_dim = [h_a_dim, z_dim]
    struct.decoder2.mu.activation = [None]
    struct.decoder2.mu.learning_rate = [learning_rate]
    struct.decoder2.mu.decay = [1]      
    struct.decoder2.sigma.layer_dim = [h_a_dim, z_dim]
    struct.decoder2.sigma.activation = [None]
    struct.decoder2.sigma.learning_rate = [learning_rate]
    struct.decoder2.sigma.decay = [1]      

    struct.decoder3.share.layer_dim = [a_dim+d_dim, h_a_dim]
    struct.decoder3.share.activation = [activation]
    struct.decoder3.share.learning_rate = [learning_rate]
    struct.decoder3.share.decay = [1]                
    struct.decoder3.mu.layer_dim = [h_a_dim, z_dim]
    struct.decoder3.mu.activation = [None]
    struct.decoder3.mu.learning_rate = [learning_rate]
    struct.decoder3.mu.decay = [1]      
    struct.decoder3.sigma.layer_dim = [h_a_dim, z_dim]
    struct.decoder3.sigma.activation = [None]
    struct.decoder3.sigma.learning_rate = [learning_rate]
    struct.decoder3.sigma.decay = [1]     
    
    struct.DomainClassifier.layer_dim = [z_dim, d_dim]
    struct.DomainClassifier.activation = [T.nnet.softmax]   
    struct.DomainClassifier.learning_rate = [learning_rate, learning_rate]
    struct.DomainClassifier.decay = [1, 1]     
        
    coef = VLDF_ANN.VLDF_ANN_coef(
        alpha = 1000,
        beta = 1000,
        L = 1,
        optimize = 'Adam_update'        
    )     
             
    description = 'TwinMoon_VLDF_ANN_%s' % (coef.optimize)                
    
    features_model, test_model, trained_param = VLDF_ANN.VLDF_ANN_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches=10,
        n_epochs=200,
        k=5,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description, reconstruction=True)
    
    #print('-------------------------------------------------------------------------')    
    
    zd_S = features_model()[6][0:sample_n,:]
    zd_T = features_model()[7][0:sample_n,:]
    
    zd_S, zd_T = util.feature_tsne(zd_S, zd_T)
    
    label_zd_S = []
    label_zd_T = []
    
    for i in range(y_dim):
        label_zd_S.append( zd_S[np.where(train_labels_source[0:sample_n,i] == 1)[0], :] )
        label_zd_T.append( zd_T[np.where(train_labels_target[0:sample_n,i] == 1)[0], :] )  
        
    title = 'Xd_feature_%s' % (description)
    fts = (label_zd_S[0][:,0], label_zd_S[0][:,1], label_zd_T[0][:,0], label_zd_T[0][:,1],
           label_zd_S[1][:,0], label_zd_S[1][:,1], label_zd_T[1][:,0], label_zd_T[1][:,1])    
    label = ('Source 0', 'Target 0', 'Source 1', 'Target 1')
    color = [1, 1, 2, 2]
    marker = [1, 2, 1, 2]
    line = False    
    legend = True
    util.data2plot(title=title, fts=fts, label=label, color=color, marker=marker, line=line, legend=legend)
# Out:
# number of minibatch at one epoch: 10, batch size source : 100, target : 100
#  validation size, S:600, T:600, test size, S:400, T:400
# ... building the model
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :50.000000 %, target domain 52.250000 %
# epoch 1, minibatch 10/10, training loss -299.287094, validation loss -281.779917
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :51.000000 %, target domain 51.750000 %
# epoch 2, minibatch 10/10, training loss -263.981659, validation loss -258.619956
# epoch 3, minibatch 10/10, training loss -284.776256, validation loss -271.064435
# epoch 4, minibatch 10/10, training loss -295.595942, validation loss -302.067196
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :49.500000 %, target domain 52.000000 %
# epoch 5, minibatch 10/10, training loss -324.069012, validation loss -314.728714
#      epoch 5, minibatch 10/10, test accuracy of best model: source domain :50.500000 %, target domain 54.750000 %
# epoch 6, minibatch 10/10, training loss -322.438321, validation loss -324.584220
#      epoch 6, minibatch 10/10, test accuracy of best model: source domain :55.000000 %, target domain 57.250000 %
# epoch 7, minibatch 10/10, training loss -338.350466, validation loss -337.526168
#      epoch 7, minibatch 10/10, test accuracy of best model: source domain :56.000000 %, target domain 57.750000 %
# epoch 8, minibatch 10/10, training loss -345.216363, validation loss -343.837135
#      epoch 8, minibatch 10/10, test accuracy of best model: source domain :52.750000 %, target domain 63.000000 %
# epoch 9, minibatch 10/10, training loss -348.222636, validation loss -351.193996
#      epoch 9, minibatch 10/10, test accuracy of best model: source domain :57.250000 %, target domain 61.500000 %
# epoch 10, minibatch 10/10, training loss -356.075624, validation loss -361.593404
#      epoch 10, minibatch 10/10, test accuracy of best model: source domain :59.750000 %, target domain 69.250000 %
# epoch 11, minibatch 10/10, training loss -367.452564, validation loss -377.876482
#      epoch 11, minibatch 10/10, test accuracy of best model: source domain :62.750000 %, target domain 69.500000 %
# epoch 12, minibatch 10/10, training loss -375.676695, validation loss -373.471281
# epoch 13, minibatch 10/10, training loss -383.671485, validation loss -384.528730
#      epoch 13, minibatch 10/10, test accuracy of best model: source domain :67.250000 %, target domain 73.500000 %
# epoch 14, minibatch 10/10, training loss -397.648284, validation loss -391.579938
#      epoch 14, minibatch 10/10, test accuracy of best model: source domain :71.000000 %, target domain 75.250000 %
# epoch 15, minibatch 10/10, training loss -404.809170, validation loss -403.735004
#      epoch 15, minibatch 10/10, test accuracy of best model: source domain :72.250000 %, target domain 76.500000 %
# epoch 16, minibatch 10/10, training loss -415.993736, validation loss -410.676039
#      epoch 16, minibatch 10/10, test accuracy of best model: source domain :76.500000 %, target domain 78.750000 %
# epoch 17, minibatch 10/10, training loss -422.777826, validation loss -418.106039
#      epoch 17, minibatch 10/10, test accuracy of best model: source domain :76.250000 %, target domain 80.500000 %
# epoch 18, minibatch 10/10, training loss -428.821978, validation loss -430.620889
#      epoch 18, minibatch 10/10, test accuracy of best model: source domain :77.750000 %, target domain 82.000000 %
# epoch 19, minibatch 10/10, training loss -438.361987, validation loss -441.872895
#      epoch 19, minibatch 10/10, test accuracy of best model: source domain :79.000000 %, target domain 83.250000 %
# epoch 20, minibatch 10/10, training loss -445.352177, validation loss -438.384167
# epoch 21, minibatch 10/10, training loss -449.235435, validation loss -445.400070
#      epoch 21, minibatch 10/10, test accuracy of best model: source domain :82.000000 %, target domain 83.250000 %
# epoch 22, minibatch 10/10, training loss -452.531519, validation loss -458.804389
#      epoch 22, minibatch 10/10, test accuracy of best model: source domain :80.250000 %, target domain 83.500000 %
# epoch 23, minibatch 10/10, training loss -463.053709, validation loss -458.674206
# epoch 24, minibatch 10/10, training loss -465.377454, validation loss -465.207869
#      epoch 24, minibatch 10/10, test accuracy of best model: source domain :82.750000 %, target domain 84.500000 %
# epoch 25, minibatch 10/10, training loss -469.572681, validation loss -467.658102
#      epoch 25, minibatch 10/10, test accuracy of best model: source domain :83.000000 %, target domain 85.500000 %
# epoch 26, minibatch 10/10, training loss -475.177737, validation loss -468.572065
#      epoch 26, minibatch 10/10, test accuracy of best model: source domain :84.750000 %, target domain 84.750000 %
# epoch 27, minibatch 10/10, training loss -471.864487, validation loss -470.438187
#      epoch 27, minibatch 10/10, test accuracy of best model: source domain :86.750000 %, target domain 83.750000 %
# epoch 28, minibatch 10/10, training loss -479.761904, validation loss -476.547637
#      epoch 28, minibatch 10/10, test accuracy of best model: source domain :85.750000 %, target domain 83.000000 %
# epoch 29, minibatch 10/10, training loss -472.039449, validation loss -466.980905
# epoch 30, minibatch 10/10, training loss -482.084953, validation loss -478.659496
#      epoch 30, minibatch 10/10, test accuracy of best model: source domain :88.000000 %, target domain 82.500000 %
# epoch 31, minibatch 10/10, training loss -482.026488, validation loss -472.657174
# epoch 32, minibatch 10/10, training loss -459.247881, validation loss -451.796978
# epoch 33, minibatch 10/10, training loss -479.595291, validation loss -478.255580
# epoch 34, minibatch 10/10, training loss -473.591060, validation loss -469.273100
# epoch 35, minibatch 10/10, training loss -475.254989, validation loss -474.837250
# epoch 36, minibatch 10/10, training loss -483.649945, validation loss -480.041078
#      epoch 36, minibatch 10/10, test accuracy of best model: source domain :87.000000 %, target domain 81.500000 %
# epoch 37, minibatch 10/10, training loss -481.627039, validation loss -480.403936
#      epoch 37, minibatch 10/10, test accuracy of best model: source domain :87.500000 %, target domain 78.750000 %
# epoch 38, minibatch 10/10, training loss -489.321330, validation loss -480.191270
# epoch 39, minibatch 10/10, training loss -488.030364, validation loss -487.126216
#      epoch 39, minibatch 10/10, test accuracy of best model: source domain :87.000000 %, target domain 82.750000 %
# epoch 40, minibatch 10/10, training loss -488.968761, validation loss -480.718317
# epoch 41, minibatch 10/10, training loss -492.097622, validation loss -483.929062
# epoch 42, minibatch 10/10, training loss -491.179543, validation loss -485.468430
# epoch 43, minibatch 10/10, training loss -493.825205, validation loss -490.401847
#      epoch 43, minibatch 10/10, test accuracy of best model: source domain :88.000000 %, target domain 81.250000 %
# epoch 44, minibatch 10/10, training loss -494.020698, validation loss -486.380313
# epoch 45, minibatch 10/10, training loss -494.741325, validation loss -488.829754
# epoch 46, minibatch 10/10, training loss -496.356638, validation loss -489.547342
# epoch 47, minibatch 10/10, training loss -499.416568, validation loss -491.169398
#      epoch 47, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 79.500000 %
# epoch 48, minibatch 10/10, training loss -498.944771, validation loss -487.173529
# epoch 49, minibatch 10/10, training loss -499.148480, validation loss -492.185717
#      epoch 49, minibatch 10/10, test accuracy of best model: source domain :87.750000 %, target domain 78.500000 %
# epoch 50, minibatch 10/10, training loss -498.026474, validation loss -491.480338
# epoch 51, minibatch 10/10, training loss -502.117681, validation loss -489.894315
# epoch 52, minibatch 10/10, training loss -499.710940, validation loss -493.539402
#      epoch 52, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 78.250000 %
# epoch 53, minibatch 10/10, training loss -499.156783, validation loss -489.287106
# epoch 54, minibatch 10/10, training loss -499.454809, validation loss -492.025998
# epoch 55, minibatch 10/10, training loss -500.476475, validation loss -494.956037
#      epoch 55, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 78.250000 %
# epoch 56, minibatch 10/10, training loss -497.560696, validation loss -492.173928
# epoch 57, minibatch 10/10, training loss -501.380992, validation loss -493.166143
# epoch 58, minibatch 10/10, training loss -497.054530, validation loss -486.303900
# epoch 59, minibatch 10/10, training loss -505.202469, validation loss -495.537789
#      epoch 59, minibatch 10/10, test accuracy of best model: source domain :88.250000 %, target domain 81.000000 %
# epoch 60, minibatch 10/10, training loss -498.944761, validation loss -493.174894
# epoch 61, minibatch 10/10, training loss -498.659473, validation loss -492.311528
# epoch 62, minibatch 10/10, training loss -502.562099, validation loss -495.756569
#      epoch 62, minibatch 10/10, test accuracy of best model: source domain :89.000000 %, target domain 78.000000 %
# epoch 63, minibatch 10/10, training loss -495.864640, validation loss -484.244078
# epoch 64, minibatch 10/10, training loss -499.928088, validation loss -496.970756
#      epoch 64, minibatch 10/10, test accuracy of best model: source domain :88.250000 %, target domain 77.250000 %
# epoch 65, minibatch 10/10, training loss -494.460695, validation loss -486.226095
# epoch 66, minibatch 10/10, training loss -504.788089, validation loss -495.039049
# epoch 67, minibatch 10/10, training loss -497.079218, validation loss -491.794063
# epoch 68, minibatch 10/10, training loss -500.758195, validation loss -494.243102
# epoch 69, minibatch 10/10, training loss -503.637193, validation loss -494.231818
# epoch 70, minibatch 10/10, training loss -501.648602, validation loss -490.394159
# epoch 71, minibatch 10/10, training loss -501.790370, validation loss -492.928057
# epoch 72, minibatch 10/10, training loss -505.650247, validation loss -492.919212
# epoch 73, minibatch 10/10, training loss -498.851654, validation loss -488.103926
# epoch 74, minibatch 10/10, training loss -504.900606, validation loss -496.592674
# epoch 75, minibatch 10/10, training loss -501.896955, validation loss -493.685592
# epoch 76, minibatch 10/10, training loss -493.948712, validation loss -485.389548
# epoch 77, minibatch 10/10, training loss -514.847974, validation loss -505.810511
#      epoch 77, minibatch 10/10, test accuracy of best model: source domain :89.500000 %, target domain 76.250000 %
# epoch 78, minibatch 10/10, training loss -499.350934, validation loss -490.926311
# epoch 79, minibatch 10/10, training loss -500.063837, validation loss -489.030274
# epoch 80, minibatch 10/10, training loss -503.100014, validation loss -494.006525
# epoch 81, minibatch 10/10, training loss -499.074354, validation loss -495.057493
# epoch 82, minibatch 10/10, training loss -502.106384, validation loss -495.708869
# epoch 83, minibatch 10/10, training loss -503.422037, validation loss -495.650703
# epoch 84, minibatch 10/10, training loss -502.594298, validation loss -495.641129
# epoch 85, minibatch 10/10, training loss -505.148778, validation loss -498.192561
# epoch 86, minibatch 10/10, training loss -506.272388, validation loss -495.808620
# epoch 87, minibatch 10/10, training loss -505.239152, validation loss -497.079891
# epoch 88, minibatch 10/10, training loss -505.565077, validation loss -498.450711
# epoch 89, minibatch 10/10, training loss -503.633092, validation loss -497.371189
# epoch 90, minibatch 10/10, training loss -505.757317, validation loss -499.671601
# epoch 91, minibatch 10/10, training loss -507.884923, validation loss -497.355350
# epoch 92, minibatch 10/10, training loss -505.329085, validation loss -499.524358
# epoch 93, minibatch 10/10, training loss -506.997888, validation loss -496.507462
# epoch 94, minibatch 10/10, training loss -506.796070, validation loss -499.925190
# epoch 95, minibatch 10/10, training loss -507.912064, validation loss -501.714502
# epoch 96, minibatch 10/10, training loss -506.456352, validation loss -503.778954
# epoch 97, minibatch 10/10, training loss -507.238589, validation loss -501.764314
# epoch 98, minibatch 10/10, training loss -509.229924, validation loss -500.226284
# epoch 99, minibatch 10/10, training loss -508.696168, validation loss -499.489555
# epoch 100, minibatch 10/10, training loss -509.374005, validation loss -501.720450
# epoch 101, minibatch 10/10, training loss -509.784778, validation loss -501.869183
# epoch 102, minibatch 10/10, training loss -508.910999, validation loss -502.189310
# epoch 103, minibatch 10/10, training loss -507.452283, validation loss -499.961481
# epoch 104, minibatch 10/10, training loss -508.405046, validation loss -500.854862
# epoch 105, minibatch 10/10, training loss -510.761785, validation loss -503.660979
# epoch 106, minibatch 10/10, training loss -509.668091, validation loss -503.901012
# epoch 107, minibatch 10/10, training loss -510.036453, validation loss -504.442658
# epoch 108, minibatch 10/10, training loss -511.275591, validation loss -501.748237
# epoch 109, minibatch 10/10, training loss -513.051562, validation loss -505.564256
# epoch 110, minibatch 10/10, training loss -510.703818, validation loss -504.327692
# epoch 111, minibatch 10/10, training loss -510.995487, validation loss -506.241908
#      epoch 111, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 79.250000 %
# epoch 112, minibatch 10/10, training loss -511.523590, validation loss -508.475547
#      epoch 112, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 79.250000 %
# epoch 113, minibatch 10/10, training loss -511.261458, validation loss -508.621538
#      epoch 113, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 77.000000 %
# epoch 114, minibatch 10/10, training loss -513.741125, validation loss -504.457674
# epoch 115, minibatch 10/10, training loss -513.586691, validation loss -507.241427
# epoch 116, minibatch 10/10, training loss -511.928158, validation loss -508.085004
# epoch 117, minibatch 10/10, training loss -513.375854, validation loss -506.661558
# epoch 118, minibatch 10/10, training loss -512.288543, validation loss -506.359495
# epoch 119, minibatch 10/10, training loss -514.674182, validation loss -510.709678
#      epoch 119, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 79.000000 %
# epoch 120, minibatch 10/10, training loss -516.561381, validation loss -507.613438
# epoch 121, minibatch 10/10, training loss -514.820193, validation loss -507.330655
# epoch 122, minibatch 10/10, training loss -514.521138, validation loss -509.537166
# epoch 123, minibatch 10/10, training loss -516.023265, validation loss -510.912677
#      epoch 123, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 79.500000 %
# epoch 124, minibatch 10/10, training loss -515.611763, validation loss -507.943809
# epoch 125, minibatch 10/10, training loss -513.276392, validation loss -508.463590
# epoch 126, minibatch 10/10, training loss -518.462917, validation loss -514.334373
#      epoch 126, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 78.250000 %
# epoch 127, minibatch 10/10, training loss -515.835133, validation loss -509.703639
# epoch 128, minibatch 10/10, training loss -514.574303, validation loss -508.338535
# epoch 129, minibatch 10/10, training loss -516.283679, validation loss -512.082314
# epoch 130, minibatch 10/10, training loss -519.234475, validation loss -510.118170
# epoch 131, minibatch 10/10, training loss -516.625835, validation loss -512.751177
# epoch 132, minibatch 10/10, training loss -519.279968, validation loss -511.326860
# epoch 133, minibatch 10/10, training loss -520.222408, validation loss -511.560713
# epoch 134, minibatch 10/10, training loss -514.972816, validation loss -511.524173
# epoch 135, minibatch 10/10, training loss -518.126312, validation loss -515.162797
#      epoch 135, minibatch 10/10, test accuracy of best model: source domain :91.500000 %, target domain 79.750000 %
# epoch 136, minibatch 10/10, training loss -519.717646, validation loss -516.371096
#      epoch 136, minibatch 10/10, test accuracy of best model: source domain :91.750000 %, target domain 82.000000 %
# epoch 137, minibatch 10/10, training loss -518.250647, validation loss -509.730956
# epoch 138, minibatch 10/10, training loss -522.164623, validation loss -514.465097
# epoch 139, minibatch 10/10, training loss -519.088131, validation loss -513.644095
# epoch 140, minibatch 10/10, training loss -522.861701, validation loss -518.792895
#      epoch 140, minibatch 10/10, test accuracy of best model: source domain :93.000000 %, target domain 82.500000 %
# epoch 141, minibatch 10/10, training loss -523.094802, validation loss -519.418349
#      epoch 141, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 82.000000 %
# epoch 142, minibatch 10/10, training loss -522.525217, validation loss -515.859432
# epoch 143, minibatch 10/10, training loss -524.036548, validation loss -516.296897
# epoch 144, minibatch 10/10, training loss -525.275547, validation loss -518.019243
# epoch 145, minibatch 10/10, training loss -525.306735, validation loss -522.144894
#      epoch 145, minibatch 10/10, test accuracy of best model: source domain :93.000000 %, target domain 82.250000 %
# epoch 146, minibatch 10/10, training loss -525.721148, validation loss -522.303794
#      epoch 146, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 82.250000 %
# epoch 147, minibatch 10/10, training loss -527.680450, validation loss -520.631897
# epoch 148, minibatch 10/10, training loss -528.562895, validation loss -522.869807
#      epoch 148, minibatch 10/10, test accuracy of best model: source domain :94.250000 %, target domain 83.500000 %
# epoch 149, minibatch 10/10, training loss -528.339463, validation loss -523.949008
#      epoch 149, minibatch 10/10, test accuracy of best model: source domain :94.250000 %, target domain 82.250000 %
# epoch 150, minibatch 10/10, training loss -529.070827, validation loss -525.794630
#      epoch 150, minibatch 10/10, test accuracy of best model: source domain :94.000000 %, target domain 83.750000 %
# epoch 151, minibatch 10/10, training loss -530.585104, validation loss -525.539622
# epoch 152, minibatch 10/10, training loss -531.095979, validation loss -528.120650
#      epoch 152, minibatch 10/10, test accuracy of best model: source domain :92.250000 %, target domain 84.000000 %
# epoch 153, minibatch 10/10, training loss -531.986772, validation loss -526.644628
# epoch 154, minibatch 10/10, training loss -532.513295, validation loss -528.112476
# epoch 155, minibatch 10/10, training loss -533.818663, validation loss -527.644450
# epoch 156, minibatch 10/10, training loss -534.075331, validation loss -529.151465
#      epoch 156, minibatch 10/10, test accuracy of best model: source domain :94.750000 %, target domain 83.750000 %
# epoch 157, minibatch 10/10, training loss -535.991553, validation loss -531.639374
#      epoch 157, minibatch 10/10, test accuracy of best model: source domain :94.500000 %, target domain 85.500000 %
# epoch 158, minibatch 10/10, training loss -535.890650, validation loss -531.459746
# epoch 159, minibatch 10/10, training loss -535.862123, validation loss -532.296841
#      epoch 159, minibatch 10/10, test accuracy of best model: source domain :95.750000 %, target domain 86.500000 %
# epoch 160, minibatch 10/10, training loss -537.436987, validation loss -535.945816
#      epoch 160, minibatch 10/10, test accuracy of best model: source domain :95.500000 %, target domain 87.250000 %
# epoch 161, minibatch 10/10, training loss -538.005083, validation loss -535.904656
# epoch 162, minibatch 10/10, training loss -537.933654, validation loss -534.017732
# epoch 163, minibatch 10/10, training loss -538.966425, validation loss -534.642000
# epoch 164, minibatch 10/10, training loss -542.466668, validation loss -538.916675
#      epoch 164, minibatch 10/10, test accuracy of best model: source domain :96.250000 %, target domain 89.500000 %
# epoch 165, minibatch 10/10, training loss -542.200819, validation loss -540.025266
#      epoch 165, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 89.500000 %
# epoch 166, minibatch 10/10, training loss -541.458823, validation loss -540.771587
#      epoch 166, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 89.000000 %
# epoch 167, minibatch 10/10, training loss -542.896940, validation loss -541.877476
#      epoch 167, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 89.750000 %
# epoch 168, minibatch 10/10, training loss -546.742031, validation loss -544.507931
#      epoch 168, minibatch 10/10, test accuracy of best model: source domain :97.750000 %, target domain 90.250000 %
# epoch 169, minibatch 10/10, training loss -543.602368, validation loss -540.571348
# epoch 170, minibatch 10/10, training loss -545.178140, validation loss -539.935999
# epoch 171, minibatch 10/10, training loss -548.646442, validation loss -545.621305
#      epoch 171, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 91.500000 %
# epoch 172, minibatch 10/10, training loss -550.084933, validation loss -547.597302
#      epoch 172, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 89.750000 %
# epoch 173, minibatch 10/10, training loss -549.159060, validation loss -547.310408
# epoch 174, minibatch 10/10, training loss -547.694370, validation loss -548.203896
#      epoch 174, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 89.750000 %
# epoch 175, minibatch 10/10, training loss -551.439444, validation loss -553.240937
#      epoch 175, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 90.000000 %
# epoch 176, minibatch 10/10, training loss -551.278432, validation loss -548.406070
# epoch 177, minibatch 10/10, training loss -552.015814, validation loss -545.477215
# epoch 178, minibatch 10/10, training loss -549.816241, validation loss -549.385804
# epoch 179, minibatch 10/10, training loss -553.982537, validation loss -554.385005
#      epoch 179, minibatch 10/10, test accuracy of best model: source domain :99.500000 %, target domain 91.250000 %
# epoch 180, minibatch 10/10, training loss -552.886102, validation loss -550.772287
# epoch 181, minibatch 10/10, training loss -554.926206, validation loss -552.868254
# epoch 182, minibatch 10/10, training loss -552.146865, validation loss -551.993986
# epoch 183, minibatch 10/10, training loss -556.586079, validation loss -556.868207
#      epoch 183, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 91.500000 %
# epoch 184, minibatch 10/10, training loss -554.282688, validation loss -552.783458
# epoch 185, minibatch 10/10, training loss -556.418894, validation loss -554.400049
# epoch 186, minibatch 10/10, training loss -554.896998, validation loss -555.905667
# epoch 187, minibatch 10/10, training loss -556.083746, validation loss -555.730481
# epoch 188, minibatch 10/10, training loss -555.760982, validation loss -553.936817
# epoch 189, minibatch 10/10, training loss -557.550995, validation loss -555.613473
# epoch 190, minibatch 10/10, training loss -556.395431, validation loss -555.322021
# epoch 191, minibatch 10/10, training loss -557.122726, validation loss -558.443212
#      epoch 191, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 92.500000 %
# epoch 192, minibatch 10/10, training loss -556.983853, validation loss -560.449241
#      epoch 192, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 91.750000 %
# epoch 193, minibatch 10/10, training loss -557.674495, validation loss -556.969183
# epoch 194, minibatch 10/10, training loss -559.173044, validation loss -555.952387
# epoch 195, minibatch 10/10, training loss -557.687188, validation loss -557.033510
# epoch 196, minibatch 10/10, training loss -559.194050, validation loss -560.519996
#      epoch 196, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 92.250000 %
# epoch 197, minibatch 10/10, training loss -559.120059, validation loss -559.329518
# epoch 198, minibatch 10/10, training loss -559.794986, validation loss -558.602145
# epoch 199, minibatch 10/10, training loss -559.478693, validation loss -558.470483
# epoch 200, minibatch 10/10, training loss -560.522851, validation loss -559.127926
# Optimization complete. Best validation loss of -560.519996 obtained at iteration 1960, with train loss -559.194050
# train accuracy : source domain 99.900000 %, target domain  92.800000 %
# validation accuracy : source domain 99.333333 %, target domain  92.833333 %
# test accuracy : source domain 99.750000 %, target domain  92.250000 %
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder5_pi is constructed with hidden layer number 1
# Encoder3_share is constructed with hidden layer number 0
# Encoder3_mu is constructed with hidden layer number 0
# Encoder3_sigma is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Encoder4_share is constructed with hidden layer number 0
# Encoder4_mu is constructed with hidden layer number 0
# Encoder4_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Decoder3_share is constructed with hidden layer number 0
# Decoder3_mu is constructed with hidden layer number 0
# Decoder3_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.36310725125110521]
# -------------------------------------------------------------------------
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.071462753593731859]
