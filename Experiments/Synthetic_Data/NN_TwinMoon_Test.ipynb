# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle


import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

#add the path of Folder Model
sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import NN
import TwinMoonFeaturePlot as fp
# Out:
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: invalid argument)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    file = '/home/cwhuang/DVTL/Dataset/Synthetic_Data/Twin_moon.npy'
    data = np.load(file)
    
    train_fts_source, train_labels_source = data[0]
    valid_fts_source, valid_labels_source = data[1]
    test_fts_source, test_labels_source = data[2]
    
    train_fts_target, train_labels_target = data[3]
    valid_fts_target, valid_labels_target = data[4]
    test_fts_target, test_labels_target = data[5]
    
    source_data = [(train_fts_source, train_labels_source), (valid_fts_source, valid_labels_source), (test_fts_source, test_labels_source)]
    target_data = [(train_fts_target, train_labels_target), (valid_fts_target, valid_labels_target), (test_fts_target, test_labels_target)]        
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        
    
    coef = NN.NN_coef(        
        beta =1,
        D = 100,
        optimize = 'Adam_update'        
    )    

    x_dim = 2
    y_dim = 2
    z_dim = 5             #dimension of latent feature    
    h_dim = 10             #dimension of hidden unit      
    activation = T.nnet.sigmoid
    lr = 0.05

    struct = NN.NN_struct()        
    struct.encoder.layer_dim = [x_dim, h_dim, z_dim]
    struct.encoder.activation = [activation, activation]
    struct.encoder.learning_rate = [lr, lr]
    struct.encoder.decay = [1, 1]                
    struct.classifier.layer_dim = [z_dim, y_dim]
    struct.classifier.activation = [T.nnet.softmax]   
    struct.classifier.learning_rate = [lr, lr]
    struct.classifier.decay = [1, 1]    
        
    isMMD = 'MMD_'
    if coef.beta == 0:
        isMMD = ''        
        
    description = 'TwinMoon_NN_%s%s' % (isMMD, coef.optimize)
        
    features_model, test_model, trained_param = NN.NN_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 10,
        n_epochs=200,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description)
# Out:
# number of minibatch at one epoch: 10, batch size source : 100, target : 100
#  validation size, S:600, T:600, test size, S:400, T:400
# ... building the model
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :50.000000 %, target domain 50.000000 %
# epoch 1, minibatch 10/10, training loss 0.707270, validation loss 0.691759
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :50.000000 %, target domain 50.000000 %
# epoch 2, minibatch 10/10, training loss 0.643503, validation loss 0.628785
#      epoch 2, minibatch 10/10, test accuracy of best model: source domain :78.500000 %, target domain 81.500000 %
# epoch 3, minibatch 10/10, training loss 0.595757, validation loss 0.581736
#      epoch 3, minibatch 10/10, test accuracy of best model: source domain :81.250000 %, target domain 87.750000 %
# epoch 4, minibatch 10/10, training loss 0.577537, validation loss 0.565828
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :82.750000 %, target domain 86.750000 %
# epoch 5, minibatch 10/10, training loss 0.564493, validation loss 0.550647
#      epoch 5, minibatch 10/10, test accuracy of best model: source domain :85.250000 %, target domain 87.500000 %
# epoch 6, minibatch 10/10, training loss 0.553934, validation loss 0.547209
#      epoch 6, minibatch 10/10, test accuracy of best model: source domain :86.000000 %, target domain 86.250000 %
# epoch 7, minibatch 10/10, training loss 0.540985, validation loss 0.535248
#      epoch 7, minibatch 10/10, test accuracy of best model: source domain :87.500000 %, target domain 82.750000 %
# epoch 8, minibatch 10/10, training loss 0.526433, validation loss 0.517515
#      epoch 8, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 79.250000 %
# epoch 9, minibatch 10/10, training loss 0.511334, validation loss 0.496682
#      epoch 9, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 76.250000 %
# epoch 10, minibatch 10/10, training loss 0.498890, validation loss 0.474022
#      epoch 10, minibatch 10/10, test accuracy of best model: source domain :89.750000 %, target domain 76.000000 %
# epoch 11, minibatch 10/10, training loss 0.490197, validation loss 0.461217
#      epoch 11, minibatch 10/10, test accuracy of best model: source domain :89.750000 %, target domain 76.250000 %
# epoch 12, minibatch 10/10, training loss 0.483430, validation loss 0.452243
#      epoch 12, minibatch 10/10, test accuracy of best model: source domain :90.000000 %, target domain 76.250000 %
# epoch 13, minibatch 10/10, training loss 0.478418, validation loss 0.442962
#      epoch 13, minibatch 10/10, test accuracy of best model: source domain :90.000000 %, target domain 76.250000 %
# epoch 14, minibatch 10/10, training loss 0.474669, validation loss 0.438119
#      epoch 14, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 76.000000 %
# epoch 15, minibatch 10/10, training loss 0.471961, validation loss 0.433617
#      epoch 15, minibatch 10/10, test accuracy of best model: source domain :90.250000 %, target domain 76.250000 %
# epoch 16, minibatch 10/10, training loss 0.469835, validation loss 0.430722
#      epoch 16, minibatch 10/10, test accuracy of best model: source domain :90.500000 %, target domain 76.000000 %
# epoch 17, minibatch 10/10, training loss 0.468129, validation loss 0.428042
#      epoch 17, minibatch 10/10, test accuracy of best model: source domain :90.500000 %, target domain 76.000000 %
# epoch 18, minibatch 10/10, training loss 0.466656, validation loss 0.426319
#      epoch 18, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 76.000000 %
# epoch 19, minibatch 10/10, training loss 0.465379, validation loss 0.424028
#      epoch 19, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 76.000000 %
# epoch 20, minibatch 10/10, training loss 0.464157, validation loss 0.423088
#      epoch 20, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 76.000000 %
# epoch 21, minibatch 10/10, training loss 0.463091, validation loss 0.420694
#      epoch 21, minibatch 10/10, test accuracy of best model: source domain :90.750000 %, target domain 76.250000 %
# epoch 22, minibatch 10/10, training loss 0.462082, validation loss 0.421051
# epoch 23, minibatch 10/10, training loss 0.461154, validation loss 0.417964
#      epoch 23, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 76.250000 %
# epoch 24, minibatch 10/10, training loss 0.460383, validation loss 0.419559
# epoch 25, minibatch 10/10, training loss 0.458971, validation loss 0.416116
#      epoch 25, minibatch 10/10, test accuracy of best model: source domain :91.500000 %, target domain 76.250000 %
# epoch 26, minibatch 10/10, training loss 0.458055, validation loss 0.416488
# epoch 27, minibatch 10/10, training loss 0.456984, validation loss 0.413663
#      epoch 27, minibatch 10/10, test accuracy of best model: source domain :91.500000 %, target domain 76.250000 %
# epoch 28, minibatch 10/10, training loss 0.456084, validation loss 0.414150
# epoch 29, minibatch 10/10, training loss 0.454819, validation loss 0.411040
#      epoch 29, minibatch 10/10, test accuracy of best model: source domain :91.500000 %, target domain 76.250000 %
# epoch 30, minibatch 10/10, training loss 0.453822, validation loss 0.411180
# epoch 31, minibatch 10/10, training loss 0.452502, validation loss 0.407965
#      epoch 31, minibatch 10/10, test accuracy of best model: source domain :91.750000 %, target domain 76.500000 %
# epoch 32, minibatch 10/10, training loss 0.451409, validation loss 0.407956
#      epoch 32, minibatch 10/10, test accuracy of best model: source domain :92.250000 %, target domain 76.500000 %
# epoch 33, minibatch 10/10, training loss 0.449979, validation loss 0.404475
#      epoch 33, minibatch 10/10, test accuracy of best model: source domain :91.750000 %, target domain 76.750000 %
# epoch 34, minibatch 10/10, training loss 0.448770, validation loss 0.404346
#      epoch 34, minibatch 10/10, test accuracy of best model: source domain :92.250000 %, target domain 77.000000 %
# epoch 35, minibatch 10/10, training loss 0.447232, validation loss 0.400538
#      epoch 35, minibatch 10/10, test accuracy of best model: source domain :91.750000 %, target domain 77.000000 %
# epoch 36, minibatch 10/10, training loss 0.445903, validation loss 0.400380
#      epoch 36, minibatch 10/10, test accuracy of best model: source domain :92.250000 %, target domain 77.000000 %
# epoch 37, minibatch 10/10, training loss 0.444265, validation loss 0.396220
#      epoch 37, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 77.000000 %
# epoch 38, minibatch 10/10, training loss 0.442819, validation loss 0.396132
#      epoch 38, minibatch 10/10, test accuracy of best model: source domain :92.250000 %, target domain 77.250000 %
# epoch 39, minibatch 10/10, training loss 0.441114, validation loss 0.391641
#      epoch 39, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 77.000000 %
# epoch 40, minibatch 10/10, training loss 0.439567, validation loss 0.391785
# epoch 41, minibatch 10/10, training loss 0.437842, validation loss 0.386978
#      epoch 41, minibatch 10/10, test accuracy of best model: source domain :92.500000 %, target domain 77.250000 %
# epoch 42, minibatch 10/10, training loss 0.436225, validation loss 0.387599
# epoch 43, minibatch 10/10, training loss 0.434542, validation loss 0.382409
#      epoch 43, minibatch 10/10, test accuracy of best model: source domain :93.000000 %, target domain 77.500000 %
# epoch 44, minibatch 10/10, training loss 0.432908, validation loss 0.383930
# epoch 45, minibatch 10/10, training loss 0.431331, validation loss 0.378045
#      epoch 45, minibatch 10/10, test accuracy of best model: source domain :93.000000 %, target domain 77.500000 %
# epoch 46, minibatch 10/10, training loss 0.429788, validation loss 0.381174
# epoch 47, minibatch 10/10, training loss 0.428329, validation loss 0.373965
#      epoch 47, minibatch 10/10, test accuracy of best model: source domain :93.500000 %, target domain 77.500000 %
# epoch 48, minibatch 10/10, training loss 0.427058, validation loss 0.379515
# epoch 49, minibatch 10/10, training loss 0.425397, validation loss 0.370355
#      epoch 49, minibatch 10/10, test accuracy of best model: source domain :94.000000 %, target domain 78.000000 %
# epoch 50, minibatch 10/10, training loss 0.424336, validation loss 0.377777
# epoch 51, minibatch 10/10, training loss 0.422034, validation loss 0.367660
#      epoch 51, minibatch 10/10, test accuracy of best model: source domain :94.250000 %, target domain 78.500000 %
# epoch 52, minibatch 10/10, training loss 0.421030, validation loss 0.374752
# epoch 53, minibatch 10/10, training loss 0.418974, validation loss 0.365699
#      epoch 53, minibatch 10/10, test accuracy of best model: source domain :94.750000 %, target domain 78.500000 %
# epoch 54, minibatch 10/10, training loss 0.418157, validation loss 0.372301
# epoch 55, minibatch 10/10, training loss 0.416342, validation loss 0.364062
#      epoch 55, minibatch 10/10, test accuracy of best model: source domain :95.000000 %, target domain 79.000000 %
# epoch 56, minibatch 10/10, training loss 0.415650, validation loss 0.370173
# epoch 57, minibatch 10/10, training loss 0.413959, validation loss 0.362439
#      epoch 57, minibatch 10/10, test accuracy of best model: source domain :95.000000 %, target domain 79.500000 %
# epoch 58, minibatch 10/10, training loss 0.413368, validation loss 0.368296
# epoch 59, minibatch 10/10, training loss 0.411762, validation loss 0.360752
#      epoch 59, minibatch 10/10, test accuracy of best model: source domain :96.000000 %, target domain 80.000000 %
# epoch 60, minibatch 10/10, training loss 0.411276, validation loss 0.366661
# epoch 61, minibatch 10/10, training loss 0.409678, validation loss 0.359143
#      epoch 61, minibatch 10/10, test accuracy of best model: source domain :96.500000 %, target domain 80.000000 %
# epoch 62, minibatch 10/10, training loss 0.409268, validation loss 0.365008
# epoch 63, minibatch 10/10, training loss 0.407689, validation loss 0.357560
#      epoch 63, minibatch 10/10, test accuracy of best model: source domain :96.500000 %, target domain 80.000000 %
# epoch 64, minibatch 10/10, training loss 0.407338, validation loss 0.363431
# epoch 65, minibatch 10/10, training loss 0.405758, validation loss 0.356054
#      epoch 65, minibatch 10/10, test accuracy of best model: source domain :96.500000 %, target domain 79.750000 %
# epoch 66, minibatch 10/10, training loss 0.405424, validation loss 0.361837
# epoch 67, minibatch 10/10, training loss 0.403867, validation loss 0.354639
#      epoch 67, minibatch 10/10, test accuracy of best model: source domain :96.750000 %, target domain 79.750000 %
# epoch 68, minibatch 10/10, training loss 0.403517, validation loss 0.360264
# epoch 69, minibatch 10/10, training loss 0.401998, validation loss 0.353378
#      epoch 69, minibatch 10/10, test accuracy of best model: source domain :96.750000 %, target domain 80.000000 %
# epoch 70, minibatch 10/10, training loss 0.401620, validation loss 0.358714
# epoch 71, minibatch 10/10, training loss 0.400160, validation loss 0.352272
#      epoch 71, minibatch 10/10, test accuracy of best model: source domain :97.000000 %, target domain 80.000000 %
# epoch 72, minibatch 10/10, training loss 0.399786, validation loss 0.357209
# epoch 73, minibatch 10/10, training loss 0.398387, validation loss 0.351209
#      epoch 73, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 80.000000 %
# epoch 74, minibatch 10/10, training loss 0.398061, validation loss 0.355710
# epoch 75, minibatch 10/10, training loss 0.396715, validation loss 0.350033
#      epoch 75, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 80.000000 %
# epoch 76, minibatch 10/10, training loss 0.396461, validation loss 0.354181
# epoch 77, minibatch 10/10, training loss 0.395153, validation loss 0.348711
#      epoch 77, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 80.000000 %
# epoch 78, minibatch 10/10, training loss 0.394969, validation loss 0.352626
# epoch 79, minibatch 10/10, training loss 0.393688, validation loss 0.347320
#      epoch 79, minibatch 10/10, test accuracy of best model: source domain :97.500000 %, target domain 80.000000 %
# epoch 80, minibatch 10/10, training loss 0.393558, validation loss 0.351060
# epoch 81, minibatch 10/10, training loss 0.392303, validation loss 0.345924
#      epoch 81, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 80.000000 %
# epoch 82, minibatch 10/10, training loss 0.392213, validation loss 0.349493
# epoch 83, minibatch 10/10, training loss 0.390984, validation loss 0.344544
#      epoch 83, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 80.000000 %
# epoch 84, minibatch 10/10, training loss 0.390922, validation loss 0.347940
# epoch 85, minibatch 10/10, training loss 0.389722, validation loss 0.343185
#      epoch 85, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 80.250000 %
# epoch 86, minibatch 10/10, training loss 0.389679, validation loss 0.346411
# epoch 87, minibatch 10/10, training loss 0.388504, validation loss 0.341854
#      epoch 87, minibatch 10/10, test accuracy of best model: source domain :98.250000 %, target domain 80.000000 %
# epoch 88, minibatch 10/10, training loss 0.388475, validation loss 0.344907
# epoch 89, minibatch 10/10, training loss 0.387325, validation loss 0.340550
#      epoch 89, minibatch 10/10, test accuracy of best model: source domain :98.250000 %, target domain 80.000000 %
# epoch 90, minibatch 10/10, training loss 0.387305, validation loss 0.343430
# epoch 91, minibatch 10/10, training loss 0.386178, validation loss 0.339269
#      epoch 91, minibatch 10/10, test accuracy of best model: source domain :98.250000 %, target domain 80.000000 %
# epoch 92, minibatch 10/10, training loss 0.386165, validation loss 0.341976
# epoch 93, minibatch 10/10, training loss 0.385058, validation loss 0.338007
#      epoch 93, minibatch 10/10, test accuracy of best model: source domain :98.250000 %, target domain 80.000000 %
# epoch 94, minibatch 10/10, training loss 0.385051, validation loss 0.340544
# epoch 95, minibatch 10/10, training loss 0.383961, validation loss 0.336760
#      epoch 95, minibatch 10/10, test accuracy of best model: source domain :98.250000 %, target domain 80.000000 %
# epoch 96, minibatch 10/10, training loss 0.383959, validation loss 0.339129
# epoch 97, minibatch 10/10, training loss 0.382886, validation loss 0.335523
#      epoch 97, minibatch 10/10, test accuracy of best model: source domain :98.500000 %, target domain 79.750000 %
# epoch 98, minibatch 10/10, training loss 0.382888, validation loss 0.337729
# epoch 99, minibatch 10/10, training loss 0.381830, validation loss 0.334294
#      epoch 99, minibatch 10/10, test accuracy of best model: source domain :98.500000 %, target domain 79.750000 %
# epoch 100, minibatch 10/10, training loss 0.381835, validation loss 0.336343
# epoch 101, minibatch 10/10, training loss 0.380791, validation loss 0.333071
#      epoch 101, minibatch 10/10, test accuracy of best model: source domain :98.500000 %, target domain 79.750000 %
# epoch 102, minibatch 10/10, training loss 0.380798, validation loss 0.334970
# epoch 103, minibatch 10/10, training loss 0.379767, validation loss 0.331852
#      epoch 103, minibatch 10/10, test accuracy of best model: source domain :98.500000 %, target domain 79.750000 %
# epoch 104, minibatch 10/10, training loss 0.379776, validation loss 0.333609
# epoch 105, minibatch 10/10, training loss 0.378756, validation loss 0.330636
#      epoch 105, minibatch 10/10, test accuracy of best model: source domain :98.500000 %, target domain 79.750000 %
# epoch 106, minibatch 10/10, training loss 0.378766, validation loss 0.332258
# epoch 107, minibatch 10/10, training loss 0.377753, validation loss 0.329420
#      epoch 107, minibatch 10/10, test accuracy of best model: source domain :98.750000 %, target domain 79.750000 %
# epoch 108, minibatch 10/10, training loss 0.377762, validation loss 0.330911
# epoch 109, minibatch 10/10, training loss 0.376752, validation loss 0.328198
#      epoch 109, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.750000 %
# epoch 110, minibatch 10/10, training loss 0.376755, validation loss 0.329557
# epoch 111, minibatch 10/10, training loss 0.375743, validation loss 0.326957
#      epoch 111, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.750000 %
# epoch 112, minibatch 10/10, training loss 0.375735, validation loss 0.328169
# epoch 113, minibatch 10/10, training loss 0.374725, validation loss 0.325678
#      epoch 113, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.750000 %
# epoch 114, minibatch 10/10, training loss 0.374722, validation loss 0.326721
# epoch 115, minibatch 10/10, training loss 0.373746, validation loss 0.324358
#      epoch 115, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.750000 %
# epoch 116, minibatch 10/10, training loss 0.373761, validation loss 0.325257
# epoch 117, minibatch 10/10, training loss 0.372802, validation loss 0.323032
#      epoch 117, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.500000 %
# epoch 118, minibatch 10/10, training loss 0.372825, validation loss 0.323811
# epoch 119, minibatch 10/10, training loss 0.371880, validation loss 0.321695
#      epoch 119, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.500000 %
# epoch 120, minibatch 10/10, training loss 0.371934, validation loss 0.322418
# epoch 121, minibatch 10/10, training loss 0.370991, validation loss 0.320477
#      epoch 121, minibatch 10/10, test accuracy of best model: source domain :99.000000 %, target domain 79.500000 %
# epoch 122, minibatch 10/10, training loss 0.371075, validation loss 0.321187
# epoch 123, minibatch 10/10, training loss 0.370132, validation loss 0.319396
#      epoch 123, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 124, minibatch 10/10, training loss 0.370240, validation loss 0.320013
# epoch 125, minibatch 10/10, training loss 0.369301, validation loss 0.318345
#      epoch 125, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 126, minibatch 10/10, training loss 0.369429, validation loss 0.318864
# epoch 127, minibatch 10/10, training loss 0.368499, validation loss 0.317344
#      epoch 127, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 128, minibatch 10/10, training loss 0.368648, validation loss 0.317769
# epoch 129, minibatch 10/10, training loss 0.367730, validation loss 0.316398
#      epoch 129, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 130, minibatch 10/10, training loss 0.367894, validation loss 0.316731
# epoch 131, minibatch 10/10, training loss 0.366988, validation loss 0.315485
#      epoch 131, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 132, minibatch 10/10, training loss 0.367163, validation loss 0.315739
# epoch 133, minibatch 10/10, training loss 0.366269, validation loss 0.314594
#      epoch 133, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 134, minibatch 10/10, training loss 0.366453, validation loss 0.314783
# epoch 135, minibatch 10/10, training loss 0.365574, validation loss 0.313721
#      epoch 135, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 79.500000 %
# epoch 136, minibatch 10/10, training loss 0.365765, validation loss 0.313857
# epoch 137, minibatch 10/10, training loss 0.364902, validation loss 0.312867
#      epoch 137, minibatch 10/10, test accuracy of best model: source domain :99.500000 %, target domain 79.500000 %
# epoch 138, minibatch 10/10, training loss 0.365099, validation loss 0.312960
# epoch 139, minibatch 10/10, training loss 0.364252, validation loss 0.312035
#      epoch 139, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 79.500000 %
# epoch 140, minibatch 10/10, training loss 0.364457, validation loss 0.312091
# epoch 141, minibatch 10/10, training loss 0.363626, validation loss 0.311227
#      epoch 141, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 142, minibatch 10/10, training loss 0.363837, validation loss 0.311251
# epoch 143, minibatch 10/10, training loss 0.363022, validation loss 0.310444
#      epoch 143, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 144, minibatch 10/10, training loss 0.363240, validation loss 0.310438
#      epoch 144, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 145, minibatch 10/10, training loss 0.362440, validation loss 0.309686
#      epoch 145, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 146, minibatch 10/10, training loss 0.362664, validation loss 0.309653
#      epoch 146, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 147, minibatch 10/10, training loss 0.361880, validation loss 0.308953
#      epoch 147, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 148, minibatch 10/10, training loss 0.362109, validation loss 0.308894
#      epoch 148, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 149, minibatch 10/10, training loss 0.361340, validation loss 0.308243
#      epoch 149, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 150, minibatch 10/10, training loss 0.361574, validation loss 0.308161
#      epoch 150, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 151, minibatch 10/10, training loss 0.360821, validation loss 0.307558
#      epoch 151, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 152, minibatch 10/10, training loss 0.361060, validation loss 0.307452
#      epoch 152, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 153, minibatch 10/10, training loss 0.360321, validation loss 0.306895
#      epoch 153, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.500000 %
# epoch 154, minibatch 10/10, training loss 0.360564, validation loss 0.306767
#      epoch 154, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 155, minibatch 10/10, training loss 0.359840, validation loss 0.306254
#      epoch 155, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 156, minibatch 10/10, training loss 0.360086, validation loss 0.306104
#      epoch 156, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 157, minibatch 10/10, training loss 0.359378, validation loss 0.305635
#      epoch 157, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 158, minibatch 10/10, training loss 0.359626, validation loss 0.305462
#      epoch 158, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 159, minibatch 10/10, training loss 0.358933, validation loss 0.305035
#      epoch 159, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 160, minibatch 10/10, training loss 0.359183, validation loss 0.304840
#      epoch 160, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 161, minibatch 10/10, training loss 0.358505, validation loss 0.304454
#      epoch 161, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 162, minibatch 10/10, training loss 0.358756, validation loss 0.304237
#      epoch 162, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 163, minibatch 10/10, training loss 0.358093, validation loss 0.303892
#      epoch 163, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 164, minibatch 10/10, training loss 0.358344, validation loss 0.303652
#      epoch 164, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 165, minibatch 10/10, training loss 0.357697, validation loss 0.303348
#      epoch 165, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 166, minibatch 10/10, training loss 0.357947, validation loss 0.303084
#      epoch 166, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.500000 %
# epoch 167, minibatch 10/10, training loss 0.357315, validation loss 0.302821
#      epoch 167, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 168, minibatch 10/10, training loss 0.357564, validation loss 0.302532
#      epoch 168, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.250000 %
# epoch 169, minibatch 10/10, training loss 0.356948, validation loss 0.302310
#      epoch 169, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.250000 %
# epoch 170, minibatch 10/10, training loss 0.357195, validation loss 0.301995
#      epoch 170, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.250000 %
# epoch 171, minibatch 10/10, training loss 0.356595, validation loss 0.301815
#      epoch 171, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.000000 %
# epoch 172, minibatch 10/10, training loss 0.356838, validation loss 0.301473
#      epoch 172, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.250000 %
# epoch 173, minibatch 10/10, training loss 0.356255, validation loss 0.301336
#      epoch 173, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.000000 %
# epoch 174, minibatch 10/10, training loss 0.356493, validation loss 0.300965
#      epoch 174, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 175, minibatch 10/10, training loss 0.355928, validation loss 0.300872
#      epoch 175, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.000000 %
# epoch 176, minibatch 10/10, training loss 0.356159, validation loss 0.300471
#      epoch 176, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 177, minibatch 10/10, training loss 0.355612, validation loss 0.300422
#      epoch 177, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.000000 %
# epoch 178, minibatch 10/10, training loss 0.355836, validation loss 0.299990
#      epoch 178, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 179, minibatch 10/10, training loss 0.355308, validation loss 0.299987
#      epoch 179, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 79.000000 %
# epoch 180, minibatch 10/10, training loss 0.355523, validation loss 0.299523
#      epoch 180, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 181, minibatch 10/10, training loss 0.355015, validation loss 0.299565
# epoch 182, minibatch 10/10, training loss 0.355219, validation loss 0.299069
#      epoch 182, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 183, minibatch 10/10, training loss 0.354732, validation loss 0.299157
# epoch 184, minibatch 10/10, training loss 0.354925, validation loss 0.298627
#      epoch 184, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 185, minibatch 10/10, training loss 0.354458, validation loss 0.298761
# epoch 186, minibatch 10/10, training loss 0.354639, validation loss 0.298198
#      epoch 186, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 187, minibatch 10/10, training loss 0.354194, validation loss 0.298378
# epoch 188, minibatch 10/10, training loss 0.354360, validation loss 0.297780
#      epoch 188, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 189, minibatch 10/10, training loss 0.353937, validation loss 0.298006
# epoch 190, minibatch 10/10, training loss 0.354090, validation loss 0.297374
#      epoch 190, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 191, minibatch 10/10, training loss 0.353689, validation loss 0.297645
# epoch 192, minibatch 10/10, training loss 0.353826, validation loss 0.296979
#      epoch 192, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 193, minibatch 10/10, training loss 0.353448, validation loss 0.297294
# epoch 194, minibatch 10/10, training loss 0.353570, validation loss 0.296595
#      epoch 194, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 195, minibatch 10/10, training loss 0.353214, validation loss 0.296953
# epoch 196, minibatch 10/10, training loss 0.353320, validation loss 0.296220
#      epoch 196, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 197, minibatch 10/10, training loss 0.352986, validation loss 0.296621
# epoch 198, minibatch 10/10, training loss 0.353076, validation loss 0.295855
#      epoch 198, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# epoch 199, minibatch 10/10, training loss 0.352765, validation loss 0.296298
# epoch 200, minibatch 10/10, training loss 0.352838, validation loss 0.295498
#      epoch 200, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 80.000000 %
# Optimization complete. Best validation loss of 0.295498 obtained at iteration 2000, with train loss 0.352838
# train accuracy : source domain 99.900000 %, target domain  78.500000 %
# validation accuracy : source domain 99.833333 %, target domain  80.500000 %
# test accuracy : source domain 100.000000 %, target domain  80.000000 %
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.048561261284635275]
# -------------------------------------------------------------------------
