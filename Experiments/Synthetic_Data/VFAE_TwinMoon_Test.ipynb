# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

#add the path of Folder Model
sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import VFAE

import TwinMoonFeaturePlot as fp
# Out:
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: invalid argument)

# %%
'''Model Construct'''
if __name__ == '__main__':

    file = '/home/cwhuang/DVTL/Dataset/Synthetic_Data/Twin_moon.npy'
    data = np.load(file)
    
    train_fts_source, train_labels_source = data[0]
    valid_fts_source, valid_labels_source = data[1]
    test_fts_source, test_labels_source = data[2]
    
    train_fts_target, train_labels_target = data[3]
    valid_fts_target, valid_labels_target = data[4]
    test_fts_target, test_labels_target = data[5]
    
    source_data = [(train_fts_source, train_labels_source), (valid_fts_source, valid_labels_source), (test_fts_source, test_labels_source)]
    target_data = [(train_fts_target, train_labels_target), (valid_fts_target, valid_labels_target), (test_fts_target, test_labels_target)]   
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        
        
    x_dim = 2
    y_dim = 2   
    d_dim = 2
    z_dim = 10                #dimension of latent feature
    a_dim = 5               #dimension of prior of latent feature    
    h_zy_dim = 10            #dimension of hidden unit  
    h_ay_dim = 10
    h_y_dim = 10
    learning_rate = 0.01
    activation = T.nnet.sigmoid

    struct = VFAE.VFAE_struct()    
    encoder_template = nn.NN_struct()

    struct.encoder1.share.layer_dim = [x_dim+d_dim, h_zy_dim]
    struct.encoder1.share.activation = [activation]
    struct.encoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.share.decay = [1, 1]                

    struct.encoder1.mu.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.mu.activation = [None]
    struct.encoder1.mu.learning_rate = [learning_rate]
    struct.encoder1.mu.decay = [1, 1]      
    struct.encoder1.sigma.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.sigma.activation = [None]
    struct.encoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.sigma.decay = [1, 1]   
    
    struct.encoder2.share.layer_dim = [z_dim+y_dim, h_ay_dim]
    struct.encoder2.share.activation = [activation]
    struct.encoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.share.decay = [1, 1]                
    struct.encoder2.mu.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.mu.activation = [None]
    struct.encoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.mu.decay = [1, 1]      
    struct.encoder2.sigma.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.sigma.activation = [None]
    struct.encoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.sigma.decay = [1, 1]
    
    
    struct.encoder3.layer_dim = [z_dim, h_y_dim, y_dim]
    struct.encoder3.activation = [activation, T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]     
    
    '''    
    struct.encoder3.layer_dim = [z_dim, y_dim]
    struct.encoder3.activation = [T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]
    '''
    
    struct.decoder1.share.layer_dim = [z_dim+d_dim, h_zy_dim]
    struct.decoder1.share.activation = [activation]
    struct.decoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.share.decay = [1, 1]                
    struct.decoder1.mu.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.mu.activation = [None]
    struct.decoder1.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.mu.decay = [1, 1]      
    struct.decoder1.sigma.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.sigma.activation = [None]
    struct.decoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.sigma.decay = [1, 1]      
    
    struct.decoder2.share.layer_dim = [a_dim+y_dim, h_ay_dim]
    struct.decoder2.share.activation = [activation]
    struct.decoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.share.decay = [1, 1]                
    struct.decoder2.mu.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.mu.activation = [None]
    struct.decoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.mu.decay = [1, 1]      
    struct.decoder2.sigma.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.sigma.activation = [None]
    struct.decoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.sigma.decay = [1, 1]      
    
    coef = VFAE.VFAE_coef(
        alpha = 1000,
        beta = 100,
        chi = 1,
        D = 100,
        L = 1,
        optimize = 'Adam_update'     
    )
    
    isMMD = 'MMD_'
    if coef.beta == 0:
        isMMD = ''                
    description = 'TwinMoonSp_VFAE_%s%s' % (isMMD, coef.optimize)  
    
    features_model, test_model, trained_param = VFAE.VFAE_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches=10,
        n_epochs=200,
        struct = struct,
        coef = coef,
        description = description
    )
    
    sample_n = 200
    fp.features_plot(features_model, test_model, source_data, target_data, sample_n, description, reconstruction=True)
# Out:
# number of minibatch at one epoch: 10, batch size source : 100, target : 100
#  validation size, S:600, T:600, test size, S:400, T:400
# ... building the model
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 1
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 1
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 1
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :49.500000 %, target domain 46.750000 %
# epoch 1, minibatch 10/10, training loss 380.095097, validation loss 365.819481
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :52.000000 %, target domain 46.750000 %
# epoch 2, minibatch 10/10, training loss 368.791928, validation loss 361.393083
#      epoch 2, minibatch 10/10, test accuracy of best model: source domain :52.250000 %, target domain 54.000000 %
# epoch 3, minibatch 10/10, training loss 366.771713, validation loss 361.081286
#      epoch 3, minibatch 10/10, test accuracy of best model: source domain :57.000000 %, target domain 49.750000 %
# epoch 4, minibatch 10/10, training loss 358.757298, validation loss 353.956189
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :62.500000 %, target domain 54.500000 %
# epoch 5, minibatch 10/10, training loss 347.982556, validation loss 338.477385
#      epoch 5, minibatch 10/10, test accuracy of best model: source domain :66.750000 %, target domain 56.500000 %
# epoch 6, minibatch 10/10, training loss 326.723656, validation loss 329.111286
#      epoch 6, minibatch 10/10, test accuracy of best model: source domain :69.000000 %, target domain 63.000000 %
# epoch 7, minibatch 10/10, training loss 297.508920, validation loss 294.481018
#      epoch 7, minibatch 10/10, test accuracy of best model: source domain :74.500000 %, target domain 73.250000 %
# epoch 8, minibatch 10/10, training loss 267.256581, validation loss 262.877378
#      epoch 8, minibatch 10/10, test accuracy of best model: source domain :80.250000 %, target domain 76.500000 %
# epoch 9, minibatch 10/10, training loss 251.025249, validation loss 247.478383
#      epoch 9, minibatch 10/10, test accuracy of best model: source domain :83.500000 %, target domain 81.000000 %
# epoch 10, minibatch 10/10, training loss 241.822135, validation loss 239.646327
#      epoch 10, minibatch 10/10, test accuracy of best model: source domain :84.250000 %, target domain 81.500000 %
# epoch 11, minibatch 10/10, training loss 234.875666, validation loss 236.342452
#      epoch 11, minibatch 10/10, test accuracy of best model: source domain :85.750000 %, target domain 80.750000 %
# epoch 12, minibatch 10/10, training loss 230.916328, validation loss 229.353554
#      epoch 12, minibatch 10/10, test accuracy of best model: source domain :87.500000 %, target domain 79.500000 %
# epoch 13, minibatch 10/10, training loss 228.004480, validation loss 223.657779
#      epoch 13, minibatch 10/10, test accuracy of best model: source domain :88.250000 %, target domain 80.250000 %
# epoch 14, minibatch 10/10, training loss 223.058058, validation loss 222.062665
#      epoch 14, minibatch 10/10, test accuracy of best model: source domain :86.750000 %, target domain 79.500000 %
# epoch 15, minibatch 10/10, training loss 219.848450, validation loss 220.036458
#      epoch 15, minibatch 10/10, test accuracy of best model: source domain :89.000000 %, target domain 77.500000 %
# epoch 16, minibatch 10/10, training loss 212.849252, validation loss 211.466895
#      epoch 16, minibatch 10/10, test accuracy of best model: source domain :88.250000 %, target domain 77.250000 %
# epoch 17, minibatch 10/10, training loss 202.209668, validation loss 201.660792
#      epoch 17, minibatch 10/10, test accuracy of best model: source domain :89.250000 %, target domain 78.000000 %
# epoch 18, minibatch 10/10, training loss 197.509187, validation loss 197.579849
#      epoch 18, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 78.250000 %
# epoch 19, minibatch 10/10, training loss 193.175286, validation loss 194.533902
#      epoch 19, minibatch 10/10, test accuracy of best model: source domain :88.500000 %, target domain 79.000000 %
# epoch 20, minibatch 10/10, training loss 189.728876, validation loss 193.875883
#      epoch 20, minibatch 10/10, test accuracy of best model: source domain :88.750000 %, target domain 77.750000 %
# epoch 21, minibatch 10/10, training loss 189.171531, validation loss 192.352665
#      epoch 21, minibatch 10/10, test accuracy of best model: source domain :89.500000 %, target domain 78.250000 %
# epoch 22, minibatch 10/10, training loss 179.472571, validation loss 181.660686
#      epoch 22, minibatch 10/10, test accuracy of best model: source domain :88.500000 %, target domain 77.750000 %
# epoch 23, minibatch 10/10, training loss 167.004934, validation loss 174.301705
#      epoch 23, minibatch 10/10, test accuracy of best model: source domain :89.750000 %, target domain 79.000000 %
# epoch 24, minibatch 10/10, training loss 163.172057, validation loss 172.458319
#      epoch 24, minibatch 10/10, test accuracy of best model: source domain :90.500000 %, target domain 79.250000 %
# epoch 25, minibatch 10/10, training loss 161.900810, validation loss 164.155820
#      epoch 25, minibatch 10/10, test accuracy of best model: source domain :92.000000 %, target domain 77.000000 %
# epoch 26, minibatch 10/10, training loss 152.530378, validation loss 162.293015
#      epoch 26, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 77.000000 %
# epoch 27, minibatch 10/10, training loss 154.669358, validation loss 157.203053
#      epoch 27, minibatch 10/10, test accuracy of best model: source domain :91.250000 %, target domain 78.500000 %
# epoch 28, minibatch 10/10, training loss 158.294982, validation loss 154.281067
#      epoch 28, minibatch 10/10, test accuracy of best model: source domain :90.750000 %, target domain 78.250000 %
# epoch 29, minibatch 10/10, training loss 149.334018, validation loss 157.437792
# epoch 30, minibatch 10/10, training loss 147.655458, validation loss 153.788520
#      epoch 30, minibatch 10/10, test accuracy of best model: source domain :91.000000 %, target domain 81.000000 %
# epoch 31, minibatch 10/10, training loss 151.104114, validation loss 153.558381
#      epoch 31, minibatch 10/10, test accuracy of best model: source domain :91.500000 %, target domain 81.750000 %
# epoch 32, minibatch 10/10, training loss 144.756337, validation loss 143.936476
#      epoch 32, minibatch 10/10, test accuracy of best model: source domain :92.500000 %, target domain 81.250000 %
# epoch 33, minibatch 10/10, training loss 138.489221, validation loss 140.306294
#      epoch 33, minibatch 10/10, test accuracy of best model: source domain :92.500000 %, target domain 80.000000 %
# epoch 34, minibatch 10/10, training loss 134.320326, validation loss 131.775479
#      epoch 34, minibatch 10/10, test accuracy of best model: source domain :91.750000 %, target domain 82.500000 %
# epoch 35, minibatch 10/10, training loss 133.853188, validation loss 132.633144
# epoch 36, minibatch 10/10, training loss 131.199069, validation loss 130.224310
#      epoch 36, minibatch 10/10, test accuracy of best model: source domain :93.750000 %, target domain 83.500000 %
# epoch 37, minibatch 10/10, training loss 125.121837, validation loss 125.598575
#      epoch 37, minibatch 10/10, test accuracy of best model: source domain :94.250000 %, target domain 82.000000 %
# epoch 38, minibatch 10/10, training loss 122.067770, validation loss 118.904242
#      epoch 38, minibatch 10/10, test accuracy of best model: source domain :94.250000 %, target domain 82.750000 %
# epoch 39, minibatch 10/10, training loss 111.424636, validation loss 108.633166
#      epoch 39, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 84.250000 %
# epoch 40, minibatch 10/10, training loss 107.923682, validation loss 112.199205
# epoch 41, minibatch 10/10, training loss 104.589181, validation loss 105.849969
#      epoch 41, minibatch 10/10, test accuracy of best model: source domain :97.250000 %, target domain 87.750000 %
# epoch 42, minibatch 10/10, training loss 97.125235, validation loss 101.656158
#      epoch 42, minibatch 10/10, test accuracy of best model: source domain :98.000000 %, target domain 87.500000 %
# epoch 43, minibatch 10/10, training loss 96.077456, validation loss 93.708304
#      epoch 43, minibatch 10/10, test accuracy of best model: source domain :98.750000 %, target domain 90.500000 %
# epoch 44, minibatch 10/10, training loss 91.758620, validation loss 90.438915
#      epoch 44, minibatch 10/10, test accuracy of best model: source domain :98.750000 %, target domain 89.750000 %
# epoch 45, minibatch 10/10, training loss 86.525342, validation loss 87.416233
#      epoch 45, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 91.750000 %
# epoch 46, minibatch 10/10, training loss 84.772927, validation loss 82.431326
#      epoch 46, minibatch 10/10, test accuracy of best model: source domain :99.250000 %, target domain 91.500000 %
# epoch 47, minibatch 10/10, training loss 80.754728, validation loss 81.180439
#      epoch 47, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 93.500000 %
# epoch 48, minibatch 10/10, training loss 80.644333, validation loss 76.982912
#      epoch 48, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 92.750000 %
# epoch 49, minibatch 10/10, training loss 78.033839, validation loss 73.919658
#      epoch 49, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 50, minibatch 10/10, training loss 77.961315, validation loss 75.797640
# epoch 51, minibatch 10/10, training loss 76.042309, validation loss 73.092336
#      epoch 51, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 94.000000 %
# epoch 52, minibatch 10/10, training loss 75.286883, validation loss 71.873182
#      epoch 52, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 93.500000 %
# epoch 53, minibatch 10/10, training loss 74.899564, validation loss 70.388449
#      epoch 53, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 94.500000 %
# epoch 54, minibatch 10/10, training loss 73.198569, validation loss 70.105225
#      epoch 54, minibatch 10/10, test accuracy of best model: source domain :99.500000 %, target domain 94.500000 %
# epoch 55, minibatch 10/10, training loss 72.387480, validation loss 68.694276
#      epoch 55, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.000000 %
# epoch 56, minibatch 10/10, training loss 72.117059, validation loss 66.807536
#      epoch 56, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 57, minibatch 10/10, training loss 71.154743, validation loss 67.642216
# epoch 58, minibatch 10/10, training loss 71.089398, validation loss 67.034606
# epoch 59, minibatch 10/10, training loss 69.681282, validation loss 65.223633
#      epoch 59, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.000000 %
# epoch 60, minibatch 10/10, training loss 69.597941, validation loss 65.055454
#      epoch 60, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 61, minibatch 10/10, training loss 68.093946, validation loss 63.971104
#      epoch 61, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.000000 %
# epoch 62, minibatch 10/10, training loss 69.173222, validation loss 65.215714
# epoch 63, minibatch 10/10, training loss 68.449759, validation loss 66.038384
# epoch 64, minibatch 10/10, training loss 68.637107, validation loss 64.462343
# epoch 65, minibatch 10/10, training loss 68.177578, validation loss 63.480401
#      epoch 65, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 96.750000 %
# epoch 66, minibatch 10/10, training loss 68.437654, validation loss 62.566195
#      epoch 66, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.250000 %
# epoch 67, minibatch 10/10, training loss 66.835322, validation loss 63.044262
# epoch 68, minibatch 10/10, training loss 66.930614, validation loss 63.511250
# epoch 69, minibatch 10/10, training loss 67.577176, validation loss 62.488786
#      epoch 69, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.500000 %
# epoch 70, minibatch 10/10, training loss 67.316073, validation loss 62.484380
#      epoch 70, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 95.250000 %
# epoch 71, minibatch 10/10, training loss 66.646588, validation loss 61.827486
#      epoch 71, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.500000 %
# epoch 72, minibatch 10/10, training loss 66.251782, validation loss 62.011959
# epoch 73, minibatch 10/10, training loss 65.851472, validation loss 62.967333
# epoch 74, minibatch 10/10, training loss 66.261692, validation loss 61.184504
#      epoch 74, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 94.500000 %
# epoch 75, minibatch 10/10, training loss 64.762470, validation loss 60.787585
#      epoch 75, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.500000 %
# epoch 76, minibatch 10/10, training loss 65.888848, validation loss 58.792160
#      epoch 76, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.250000 %
# epoch 77, minibatch 10/10, training loss 65.420693, validation loss 60.787189
# epoch 78, minibatch 10/10, training loss 65.927119, validation loss 58.415308
#      epoch 78, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.000000 %
# epoch 79, minibatch 10/10, training loss 64.863470, validation loss 59.294013
# epoch 80, minibatch 10/10, training loss 64.235633, validation loss 59.722124
# epoch 81, minibatch 10/10, training loss 65.219976, validation loss 60.249922
# epoch 82, minibatch 10/10, training loss 64.213193, validation loss 59.474242
# epoch 83, minibatch 10/10, training loss 63.666834, validation loss 57.955394
#      epoch 83, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 84, minibatch 10/10, training loss 64.724259, validation loss 60.243291
# epoch 85, minibatch 10/10, training loss 64.353828, validation loss 57.688209
#      epoch 85, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.250000 %
# epoch 86, minibatch 10/10, training loss 64.056238, validation loss 58.113568
# epoch 87, minibatch 10/10, training loss 64.014163, validation loss 57.348521
#      epoch 87, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 94.750000 %
# epoch 88, minibatch 10/10, training loss 63.340910, validation loss 59.367455
# epoch 89, minibatch 10/10, training loss 62.880960, validation loss 59.439871
# epoch 90, minibatch 10/10, training loss 63.596740, validation loss 57.420232
# epoch 91, minibatch 10/10, training loss 64.142630, validation loss 58.579573
# epoch 92, minibatch 10/10, training loss 63.091046, validation loss 57.101402
#      epoch 92, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.000000 %
# epoch 93, minibatch 10/10, training loss 63.607130, validation loss 57.334633
# epoch 94, minibatch 10/10, training loss 64.133059, validation loss 56.824055
#      epoch 94, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.000000 %
# epoch 95, minibatch 10/10, training loss 63.334735, validation loss 57.456040
# epoch 96, minibatch 10/10, training loss 62.928206, validation loss 57.956156
# epoch 97, minibatch 10/10, training loss 63.407326, validation loss 57.321850
# epoch 98, minibatch 10/10, training loss 63.208007, validation loss 56.542275
#      epoch 98, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 93.500000 %
# epoch 99, minibatch 10/10, training loss 63.913972, validation loss 58.186055
# epoch 100, minibatch 10/10, training loss 63.955401, validation loss 56.644210
# epoch 101, minibatch 10/10, training loss 62.919551, validation loss 58.514834
# epoch 102, minibatch 10/10, training loss 62.696974, validation loss 56.473733
#      epoch 102, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 94.750000 %
# epoch 103, minibatch 10/10, training loss 63.242839, validation loss 56.599798
# epoch 104, minibatch 10/10, training loss 62.697460, validation loss 56.189315
#      epoch 104, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 93.750000 %
# epoch 105, minibatch 10/10, training loss 63.463297, validation loss 55.959321
#      epoch 105, minibatch 10/10, test accuracy of best model: source domain :99.750000 %, target domain 93.250000 %
# epoch 106, minibatch 10/10, training loss 62.692337, validation loss 54.736963
#      epoch 106, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.500000 %
# epoch 107, minibatch 10/10, training loss 61.634420, validation loss 56.836552
# epoch 108, minibatch 10/10, training loss 63.818924, validation loss 57.570940
# epoch 109, minibatch 10/10, training loss 63.104589, validation loss 57.372269
# epoch 110, minibatch 10/10, training loss 61.354798, validation loss 55.734695
# epoch 111, minibatch 10/10, training loss 62.023010, validation loss 55.468397
# epoch 112, minibatch 10/10, training loss 62.242222, validation loss 55.570315
# epoch 113, minibatch 10/10, training loss 61.911355, validation loss 56.026289
# epoch 114, minibatch 10/10, training loss 61.565136, validation loss 54.995135
# epoch 115, minibatch 10/10, training loss 61.273205, validation loss 55.339425
# epoch 116, minibatch 10/10, training loss 61.297911, validation loss 55.102211
# epoch 117, minibatch 10/10, training loss 61.704602, validation loss 54.783819
# epoch 118, minibatch 10/10, training loss 61.538788, validation loss 56.871141
# epoch 119, minibatch 10/10, training loss 62.166840, validation loss 57.577045
# epoch 120, minibatch 10/10, training loss 61.326203, validation loss 54.793042
# epoch 121, minibatch 10/10, training loss 61.436455, validation loss 57.296142
# epoch 122, minibatch 10/10, training loss 61.787123, validation loss 56.802863
# epoch 123, minibatch 10/10, training loss 62.429820, validation loss 55.957736
# epoch 124, minibatch 10/10, training loss 61.024065, validation loss 55.263132
# epoch 125, minibatch 10/10, training loss 62.070026, validation loss 55.751013
# epoch 126, minibatch 10/10, training loss 62.009140, validation loss 54.980548
# epoch 127, minibatch 10/10, training loss 61.531328, validation loss 55.235404
# epoch 128, minibatch 10/10, training loss 61.696712, validation loss 55.551748
# epoch 129, minibatch 10/10, training loss 60.625386, validation loss 54.763012
# epoch 130, minibatch 10/10, training loss 60.774482, validation loss 53.659552
#      epoch 130, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.250000 %
# epoch 131, minibatch 10/10, training loss 61.098922, validation loss 55.559020
# epoch 132, minibatch 10/10, training loss 61.158920, validation loss 53.573516
#      epoch 132, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.250000 %
# epoch 133, minibatch 10/10, training loss 60.740908, validation loss 55.426970
# epoch 134, minibatch 10/10, training loss 61.297032, validation loss 55.602202
# epoch 135, minibatch 10/10, training loss 61.199936, validation loss 54.765292
# epoch 136, minibatch 10/10, training loss 60.865963, validation loss 55.712709
# epoch 137, minibatch 10/10, training loss 60.526491, validation loss 54.683498
# epoch 138, minibatch 10/10, training loss 60.295636, validation loss 54.854462
# epoch 139, minibatch 10/10, training loss 61.442271, validation loss 55.243079
# epoch 140, minibatch 10/10, training loss 60.893907, validation loss 55.055870
# epoch 141, minibatch 10/10, training loss 61.609816, validation loss 54.472679
# epoch 142, minibatch 10/10, training loss 60.520371, validation loss 56.344055
# epoch 143, minibatch 10/10, training loss 61.279305, validation loss 55.375651
# epoch 144, minibatch 10/10, training loss 61.407421, validation loss 55.262414
# epoch 145, minibatch 10/10, training loss 62.196127, validation loss 53.954306
# epoch 146, minibatch 10/10, training loss 61.061124, validation loss 54.973023
# epoch 147, minibatch 10/10, training loss 60.468625, validation loss 54.228334
# epoch 148, minibatch 10/10, training loss 61.385681, validation loss 54.189313
# epoch 149, minibatch 10/10, training loss 61.469856, validation loss 55.264891
# epoch 150, minibatch 10/10, training loss 59.802331, validation loss 54.108586
# epoch 151, minibatch 10/10, training loss 60.721580, validation loss 54.737958
# epoch 152, minibatch 10/10, training loss 60.695492, validation loss 55.452871
# epoch 153, minibatch 10/10, training loss 60.825935, validation loss 53.630422
# epoch 154, minibatch 10/10, training loss 59.827508, validation loss 54.271273
# epoch 155, minibatch 10/10, training loss 62.344820, validation loss 53.872825
# epoch 156, minibatch 10/10, training loss 60.375320, validation loss 54.815423
# epoch 157, minibatch 10/10, training loss 60.897232, validation loss 54.315513
# epoch 158, minibatch 10/10, training loss 61.105808, validation loss 54.310679
# epoch 159, minibatch 10/10, training loss 61.035322, validation loss 54.035519
# epoch 160, minibatch 10/10, training loss 59.981457, validation loss 54.910909
# epoch 161, minibatch 10/10, training loss 61.622671, validation loss 54.404094
# epoch 162, minibatch 10/10, training loss 60.331621, validation loss 54.018291
# epoch 163, minibatch 10/10, training loss 59.801439, validation loss 56.430001
# epoch 164, minibatch 10/10, training loss 60.141671, validation loss 55.339374
# epoch 165, minibatch 10/10, training loss 60.432940, validation loss 53.406159
#      epoch 165, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 95.000000 %
# epoch 166, minibatch 10/10, training loss 60.243816, validation loss 53.912092
# epoch 167, minibatch 10/10, training loss 61.721586, validation loss 55.376180
# epoch 168, minibatch 10/10, training loss 60.332227, validation loss 54.111031
# epoch 169, minibatch 10/10, training loss 60.292914, validation loss 55.162527
# epoch 170, minibatch 10/10, training loss 60.489249, validation loss 54.367118
# epoch 171, minibatch 10/10, training loss 62.515740, validation loss 55.233310
# epoch 172, minibatch 10/10, training loss 60.278953, validation loss 54.586435
# epoch 173, minibatch 10/10, training loss 59.880394, validation loss 54.340123
# epoch 174, minibatch 10/10, training loss 61.381941, validation loss 54.895652
# epoch 175, minibatch 10/10, training loss 61.000645, validation loss 54.990408
# epoch 176, minibatch 10/10, training loss 60.692143, validation loss 54.028006
# epoch 177, minibatch 10/10, training loss 60.127642, validation loss 54.675677
# epoch 178, minibatch 10/10, training loss 60.409334, validation loss 53.865439
# epoch 179, minibatch 10/10, training loss 61.105751, validation loss 54.043292
# epoch 180, minibatch 10/10, training loss 59.478229, validation loss 52.956567
#      epoch 180, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.250000 %
# epoch 181, minibatch 10/10, training loss 59.870519, validation loss 54.868668
# epoch 182, minibatch 10/10, training loss 61.549631, validation loss 54.341976
# epoch 183, minibatch 10/10, training loss 60.773601, validation loss 54.097871
# epoch 184, minibatch 10/10, training loss 60.402119, validation loss 53.469022
# epoch 185, minibatch 10/10, training loss 59.492410, validation loss 52.686100
#      epoch 185, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 97.000000 %
# epoch 186, minibatch 10/10, training loss 59.385211, validation loss 53.611773
# epoch 187, minibatch 10/10, training loss 60.933436, validation loss 53.311167
# epoch 188, minibatch 10/10, training loss 60.391832, validation loss 52.669346
#      epoch 188, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.750000 %
# epoch 189, minibatch 10/10, training loss 59.154271, validation loss 51.850440
#      epoch 189, minibatch 10/10, test accuracy of best model: source domain :100.000000 %, target domain 96.000000 %
# epoch 190, minibatch 10/10, training loss 59.425068, validation loss 53.803815
# epoch 191, minibatch 10/10, training loss 60.755707, validation loss 55.041045
# epoch 192, minibatch 10/10, training loss 60.535626, validation loss 53.280362
# epoch 193, minibatch 10/10, training loss 61.779457, validation loss 52.896368
# epoch 194, minibatch 10/10, training loss 60.095071, validation loss 54.920205
# epoch 195, minibatch 10/10, training loss 60.001888, validation loss 52.874985
# epoch 196, minibatch 10/10, training loss 59.793533, validation loss 52.897231
# epoch 197, minibatch 10/10, training loss 60.557374, validation loss 54.725443
# epoch 198, minibatch 10/10, training loss 60.316894, validation loss 53.582656
# epoch 199, minibatch 10/10, training loss 58.775501, validation loss 53.331222
# epoch 200, minibatch 10/10, training loss 59.244540, validation loss 53.516930
# Optimization complete. Best validation loss of 51.850440 obtained at iteration 1890, with train loss 59.154271
# train accuracy : source domain 99.800000 %, target domain  95.700000 %
# validation accuracy : source domain 100.000000 %, target domain  94.000000 %
# test accuracy : source domain 100.000000 %, target domain  96.000000 %
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder1_share is constructed with hidden layer number 0
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 1
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 400, '...']
# ['Mean value of sigma: ', 0.15032484978785876]
# -------------------------------------------------------------------------
