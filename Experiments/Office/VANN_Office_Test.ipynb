# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import VANN

import OfficeFeaturePlot as fp
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5005)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    source_file = '/home/cwhuang/DVTL/Dataset/Office/Caltech10_SURF_L10.npy'
    target_file = '/home/cwhuang/DVTL/Dataset/Office/amazon_SURF_L10.npy'
    
    source_data = np.load(source_file)
    target_data = np.load(target_file)
    
    #source_data, target_data = DataDuplicate.DataDuplicate(source_data, target_data)   
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        

    x_dim = 800
    y_dim = 10    
    d_dim = 2    
    z_dim = 100                #dimension of latent feature
    a_dim = 50                 #dimension of prior of latent feature    
    h_zy_dim = 300             #dimension of hidden unit  
    h_ay_dim = 70
    h_y_dim = 30    
    learning_rate = 0.005    
    activation = T.nnet.sigmoid
    
    struct = VANN.VANN_struct()    
    encoder_template = nn.NN_struct()

    
    struct.encoder1.share.layer_dim = [x_dim+d_dim, 500, h_zy_dim]
    struct.encoder1.share.activation = [activation, activation]
    struct.encoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.share.decay = [1, 1]                

    struct.encoder1.mu.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.mu.activation = [None]
    struct.encoder1.mu.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.mu.decay = [1, 1]      
    struct.encoder1.sigma.layer_dim = [h_zy_dim, z_dim]
    struct.encoder1.sigma.activation = [None]
    struct.encoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder1.sigma.decay = [1, 1]   
    
    struct.encoder2.share.layer_dim = [z_dim+y_dim, h_ay_dim]
    struct.encoder2.share.activation = [ activation]
    struct.encoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.share.decay = [1, 1]                
    struct.encoder2.mu.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.mu.activation = [None]
    struct.encoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.mu.decay = [1, 1]      
    struct.encoder2.sigma.layer_dim = [h_ay_dim, a_dim]
    struct.encoder2.sigma.activation = [None]
    struct.encoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.encoder2.sigma.decay = [1, 1]
    
    '''
    struct.encoder3.layer_dim = [z_dim, h_y_dim, y_dim]
    struct.encoder3.activation = [activation, T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]     
    '''
    
    struct.encoder3.layer_dim = [z_dim, y_dim]
    struct.encoder3.activation = [ T.nnet.softmax]   
    struct.encoder3.learning_rate = [learning_rate, learning_rate]
    struct.encoder3.decay = [1, 1]     
    
    struct.decoder1.share.layer_dim = [z_dim+d_dim, h_zy_dim]
    struct.decoder1.share.activation = [activation]
    struct.decoder1.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.share.decay = [1, 1]                
    struct.decoder1.mu.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.mu.activation = [None]
    struct.decoder1.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.mu.decay = [1, 1]      
    struct.decoder1.sigma.layer_dim = [h_zy_dim, x_dim]
    struct.decoder1.sigma.activation = [None]
    struct.decoder1.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder1.sigma.decay = [1, 1]      
    
    struct.decoder2.share.layer_dim = [a_dim+y_dim, h_ay_dim]
    struct.decoder2.share.activation = [activation]
    struct.decoder2.share.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.share.decay = [1, 1]                
    struct.decoder2.mu.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.mu.activation = [None]
    struct.decoder2.mu.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.mu.decay = [1, 1]      
    struct.decoder2.sigma.layer_dim = [h_ay_dim, z_dim]
    struct.decoder2.sigma.activation = [None]
    struct.decoder2.sigma.learning_rate = [learning_rate, learning_rate]
    struct.decoder2.sigma.decay = [1, 1]       
    
    struct.DomainClassifier.layer_dim = [z_dim, 50, d_dim]
    struct.DomainClassifier.activation = [activation, T.nnet.softmax]   
    struct.DomainClassifier.learning_rate = [0.01, 0.01]
    struct.DomainClassifier.decay = [1, 1]      
    
    
    coef = VANN.VANN_coef(
        alpha = 3000,
        beta = 100,        
        L = 10,
        optimize = 'Adam_update'  
    )        
    
    description = 'Office_VANN_%s' % (coef.optimize)  
    
    
    features_model, test_model, trained_param = VANN.VANN_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 10,
        n_epochs = 100,
        k = 10,
        struct = struct,
        coef = coef,
        description = description
    )
    
    fp.features_plot(features_model, test_model, source_data, target_data, description)
# Out:
# number of minibatch at one epoch: 10, batch size source : 57, target : 48
#  validation size, S:330, T:280, test size, S:220, T:190
# ... building the model
# Encoder1_share is constructed with hidden layer number 1
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Encoder1_share is constructed with hidden layer number 1
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Encoder1_share is constructed with hidden layer number 1
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# ... training
# Initial, test accuracy: source domain :10.909091 %, target domain 11.052632 %
# epoch 1, minibatch 10/10, training loss 3784.130540, validation loss 5139.526993
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :25.454545 %, target domain 34.736842 %
# epoch 2, minibatch 10/10, training loss 2206.356388, validation loss 4381.365449
#      epoch 2, minibatch 10/10, test accuracy of best model: source domain :42.727273 %, target domain 40.526316 %
# epoch 3, minibatch 10/10, training loss 1671.182587, validation loss 4610.875335
# epoch 4, minibatch 10/10, training loss 1469.606602, validation loss 4171.065610
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :49.545455 %, target domain 55.789474 %
# epoch 5, minibatch 10/10, training loss 1388.175809, validation loss 4375.014591
# epoch 6, minibatch 10/10, training loss 1357.822057, validation loss 4417.340162
# epoch 7, minibatch 10/10, training loss 1342.799565, validation loss 4375.595249
# epoch 8, minibatch 10/10, training loss 1331.223561, validation loss 4379.419158
# epoch 9, minibatch 10/10, training loss 1324.298879, validation loss 4445.914919
# epoch 10, minibatch 10/10, training loss 1318.337412, validation loss 4596.110183
# epoch 11, minibatch 10/10, training loss 1312.098573, validation loss 4505.955242
# epoch 12, minibatch 10/10, training loss 1307.161133, validation loss 4603.630380
# epoch 13, minibatch 10/10, training loss 1305.872247, validation loss 4660.258753
# epoch 14, minibatch 10/10, training loss 1303.412980, validation loss 4683.405258
# epoch 15, minibatch 10/10, training loss 1298.495274, validation loss 4769.896919
# epoch 16, minibatch 10/10, training loss 1296.714729, validation loss 4625.177227
# epoch 17, minibatch 10/10, training loss 1295.559579, validation loss 4682.048149
# epoch 18, minibatch 10/10, training loss 1293.780726, validation loss 4666.946246
# epoch 19, minibatch 10/10, training loss 1293.204835, validation loss 4788.906475
# epoch 20, minibatch 10/10, training loss 1290.247481, validation loss 4816.329988
# epoch 21, minibatch 10/10, training loss 1292.862524, validation loss 5019.570388
# epoch 22, minibatch 10/10, training loss 1291.388375, validation loss 5085.565234
# epoch 23, minibatch 10/10, training loss 1287.940453, validation loss 4987.251991
# epoch 24, minibatch 10/10, training loss 1287.793151, validation loss 5006.541060
# epoch 25, minibatch 10/10, training loss 1286.219152, validation loss 4971.463281
# epoch 26, minibatch 10/10, training loss 1286.196770, validation loss 4819.775768
# epoch 27, minibatch 10/10, training loss 1283.101459, validation loss 4787.193027
# epoch 28, minibatch 10/10, training loss 1283.007745, validation loss 5044.386535
# epoch 29, minibatch 10/10, training loss 1281.848289, validation loss 5082.919696
# epoch 30, minibatch 10/10, training loss 1280.813767, validation loss 4766.750024
# epoch 31, minibatch 10/10, training loss 1280.237726, validation loss 4957.934926
# epoch 32, minibatch 10/10, training loss 1278.855378, validation loss 4988.518754
# epoch 33, minibatch 10/10, training loss 1277.818990, validation loss 4845.231115
# epoch 34, minibatch 10/10, training loss 1279.239608, validation loss 4957.998679
# epoch 35, minibatch 10/10, training loss 1277.124898, validation loss 5101.205295
# epoch 36, minibatch 10/10, training loss 1277.147701, validation loss 4938.016624
# epoch 37, minibatch 10/10, training loss 1276.364984, validation loss 5052.383667
# epoch 38, minibatch 10/10, training loss 1277.190729, validation loss 5153.872121
# epoch 39, minibatch 10/10, training loss 1276.124093, validation loss 5040.731820
# epoch 40, minibatch 10/10, training loss 1273.757783, validation loss 5177.204436
# epoch 41, minibatch 10/10, training loss 1273.771231, validation loss 5035.431983
# epoch 42, minibatch 10/10, training loss 1273.408398, validation loss 5056.412413
# epoch 43, minibatch 10/10, training loss 1272.187348, validation loss 4996.579239
# epoch 44, minibatch 10/10, training loss 1271.736625, validation loss 4992.152211
# epoch 45, minibatch 10/10, training loss 1271.280678, validation loss 5063.886322
# epoch 46, minibatch 10/10, training loss 1270.890807, validation loss 5044.432095
# epoch 47, minibatch 10/10, training loss 1269.200500, validation loss 5060.887152
# epoch 48, minibatch 10/10, training loss 1269.595931, validation loss 5035.288536
# epoch 49, minibatch 10/10, training loss 1269.471720, validation loss 5015.871872
# epoch 50, minibatch 10/10, training loss 1267.549064, validation loss 5164.074523
# epoch 51, minibatch 10/10, training loss 1267.036700, validation loss 5061.098733
# epoch 52, minibatch 10/10, training loss 1265.608447, validation loss 5015.615798
# epoch 53, minibatch 10/10, training loss 1265.544597, validation loss 4976.626312
# epoch 54, minibatch 10/10, training loss 1265.589598, validation loss 5076.567882
# epoch 55, minibatch 10/10, training loss 1262.657948, validation loss 5073.450044
# epoch 56, minibatch 10/10, training loss 1263.626914, validation loss 4965.982192
# epoch 57, minibatch 10/10, training loss 1263.404863, validation loss 5024.095813
# epoch 58, minibatch 10/10, training loss 1263.858635, validation loss 5060.125313
# epoch 59, minibatch 10/10, training loss 1262.287130, validation loss 5013.963358
# epoch 60, minibatch 10/10, training loss 1260.263954, validation loss 5206.467106
# epoch 61, minibatch 10/10, training loss 1261.514424, validation loss 5143.604097
# epoch 62, minibatch 10/10, training loss 1261.476380, validation loss 5011.865778
# epoch 63, minibatch 10/10, training loss 1262.507931, validation loss 5087.587257
# epoch 64, minibatch 10/10, training loss 1261.001145, validation loss 5054.065022
# epoch 65, minibatch 10/10, training loss 1260.123571, validation loss 5140.437781
# epoch 66, minibatch 10/10, training loss 1258.081759, validation loss 5078.767342
# epoch 67, minibatch 10/10, training loss 1259.086747, validation loss 5281.997373
# epoch 68, minibatch 10/10, training loss 1257.674174, validation loss 5385.930700
# epoch 69, minibatch 10/10, training loss 1256.417880, validation loss 5194.302682
# epoch 70, minibatch 10/10, training loss 1254.931573, validation loss 5265.180810
# epoch 71, minibatch 10/10, training loss 1256.026192, validation loss 5020.381153
# epoch 72, minibatch 10/10, training loss 1256.387741, validation loss 5036.269716
# epoch 73, minibatch 10/10, training loss 1254.785884, validation loss 5097.596680
# epoch 74, minibatch 10/10, training loss 1253.196422, validation loss 5198.115375
# epoch 75, minibatch 10/10, training loss 1255.197365, validation loss 5065.406406
# epoch 76, minibatch 10/10, training loss 1254.374500, validation loss 5082.143042
# epoch 77, minibatch 10/10, training loss 1253.054922, validation loss 5177.763193
# epoch 78, minibatch 10/10, training loss 1252.160206, validation loss 5218.946737
# epoch 79, minibatch 10/10, training loss 1253.729295, validation loss 5085.364158
# epoch 80, minibatch 10/10, training loss 1253.008670, validation loss 5177.903878
# epoch 81, minibatch 10/10, training loss 1251.749983, validation loss 5203.457945
# epoch 82, minibatch 10/10, training loss 1250.612731, validation loss 5035.306752
# epoch 83, minibatch 10/10, training loss 1252.014042, validation loss 5220.654591
# epoch 84, minibatch 10/10, training loss 1251.308217, validation loss 5077.548352
# epoch 85, minibatch 10/10, training loss 1251.223714, validation loss 4994.568052
# epoch 86, minibatch 10/10, training loss 1251.828040, validation loss 5120.222278
# epoch 87, minibatch 10/10, training loss 1251.027634, validation loss 5364.243612
# epoch 88, minibatch 10/10, training loss 1249.707479, validation loss 5212.673452
# epoch 89, minibatch 10/10, training loss 1249.007375, validation loss 5224.521646
# epoch 90, minibatch 10/10, training loss 1248.401692, validation loss 5143.914451
# epoch 91, minibatch 10/10, training loss 1248.101805, validation loss 5299.585580
# epoch 92, minibatch 10/10, training loss 1247.994413, validation loss 5112.949556
# epoch 93, minibatch 10/10, training loss 1248.907202, validation loss 5355.435897
# epoch 94, minibatch 10/10, training loss 1246.344739, validation loss 5201.087594
# epoch 95, minibatch 10/10, training loss 1246.351839, validation loss 5207.037981
# epoch 96, minibatch 10/10, training loss 1246.175538, validation loss 5197.712925
# epoch 97, minibatch 10/10, training loss 1246.634145, validation loss 5183.827797
# epoch 98, minibatch 10/10, training loss 1246.183215, validation loss 5115.973815
# epoch 99, minibatch 10/10, training loss 1246.090639, validation loss 5301.599879
# epoch 100, minibatch 10/10, training loss 1246.846884, validation loss 5248.446054
# Optimization complete. Best validation loss of 4171.065610 obtained at iteration 40, with train loss 1469.606602
# train accuracy : source domain 100.000000 %, target domain  44.375000 %
# validation accuracy : source domain 51.818182 %, target domain  55.357143 %
# test accuracy : source domain 49.545455 %, target domain  55.789474 %
# 100.00 - 51.82 - 49.55; 44.38 - 55.36 - 55.79
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder1_share is constructed with hidden layer number 1
# Encoder1_mu is constructed with hidden layer number 0
# Encoder1_sigma is constructed with hidden layer number 0
# Encoder3_pi is constructed with hidden layer number 0
# Encoder2_share is constructed with hidden layer number 0
# Encoder2_mu is constructed with hidden layer number 0
# Encoder2_sigma is constructed with hidden layer number 0
# Decoder1_share is constructed with hidden layer number 0
# Decoder1_mu is constructed with hidden layer number 0
# Decoder1_sigma is constructed with hidden layer number 0
# Decoder2_share is constructed with hidden layer number 0
# Decoder2_mu is constructed with hidden layer number 0
# Decoder2_sigma is constructed with hidden layer number 0
# DomainClassifier is constructed with hidden layer number 1
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 1061, '...']
# ['Computing P-values for point ', 500, ' of ', 1061, '...']
# ['Computing P-values for point ', 1000, ' of ', 1061, '...']
# ['Mean value of sigma: ', 2.1109283141875932]
