# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle

import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import DANN

import OfficeFeaturePlot as fp
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5005)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    source_file = '/home/cwhuang/DVTL/Dataset/Office/Caltech10_SURF_L10.npy'
    target_file = '/home/cwhuang/DVTL/Dataset/Office/amazon_SURF_L10.npy'

    source_data = np.load(source_file)
    target_data = np.load(target_file)
    
    #source_data, target_data = DataDuplicate.DataDuplicate(source_data, target_data)  
    
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        
    
    coef = DANN.DANN_coef(        
        beta = 2,
        optimize = 'Adam_update'           
    )    
    
    x_dim = 800
    y_dim = 10
    d_dim = 2
    z_dim = 100                #dimension of latent feature    
    h_dim = 300             #dimension of hidden unit      
    activation = T.nnet.sigmoid
    learning_rate = 0.005

    struct = DANN.DANN_struct()        
    struct.encoder.layer_dim = [x_dim, h_dim, z_dim]
    struct.encoder.activation = [activation, activation]
    struct.encoder.learning_rate = [learning_rate, learning_rate]
    struct.encoder.decay = [1, 1]                
    struct.classifier.layer_dim = [z_dim, 50, y_dim]
    struct.classifier.activation = [activation, T.nnet.softmax]   
    struct.classifier.learning_rate = [learning_rate, learning_rate]
    struct.classifier.decay = [1, 1]  
    struct.DomainClassifier.layer_dim = [z_dim, d_dim]
    struct.DomainClassifier.activation = [T.nnet.softmax]
    struct.DomainClassifier.learning_rate = [learning_rate, learning_rate]
    struct.DomainClassifier.decay = [1, 1]     
        
    description = 'Office_DANN_%s' % (coef.optimize)
    
    features_model, test_model, trained_param = DANN.DANN_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 5,
        n_epochs = 100,
        k = 10,
        struct = struct,
        coef = coef,
        description = description
    )
    
    fp.features_plot(features_model, test_model, source_data, target_data, description)
# Out:
# number of minibatch at one epoch: 5, batch size source : 114, target : 97
#  validation size, S:330, T:280, test size, S:220, T:190
# ... building the model
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 1
# DomainClassifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 1
# DomainClassifier is constructed with hidden layer number 0
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 1
# DomainClassifier is constructed with hidden layer number 0
# ... training
# Initial, test accuracy: source domain :11.363636 %, target domain 7.894737 %
# epoch 1, minibatch 5/5, training loss 0.547251, validation loss 0.967931
#      epoch 1, minibatch 5/5, test accuracy of best model: source domain :12.727273 %, target domain 14.736842 %
# epoch 2, minibatch 5/5, training loss 0.560872, validation loss 0.789895
#      epoch 2, minibatch 5/5, test accuracy of best model: source domain :20.000000 %, target domain 28.421053 %
# epoch 3, minibatch 5/5, training loss 0.359203, validation loss 0.595263
#      epoch 3, minibatch 5/5, test accuracy of best model: source domain :25.454545 %, target domain 35.263158 %
# epoch 4, minibatch 5/5, training loss 0.099671, validation loss 0.578846
#      epoch 4, minibatch 5/5, test accuracy of best model: source domain :30.909091 %, target domain 35.263158 %
# epoch 5, minibatch 5/5, training loss 0.042445, validation loss 0.607774
# epoch 6, minibatch 5/5, training loss 0.009323, validation loss 0.592466
# epoch 7, minibatch 5/5, training loss -0.083429, validation loss 0.569842
#      epoch 7, minibatch 5/5, test accuracy of best model: source domain :35.000000 %, target domain 40.000000 %
# epoch 8, minibatch 5/5, training loss -0.136567, validation loss 0.537219
#      epoch 8, minibatch 5/5, test accuracy of best model: source domain :37.272727 %, target domain 42.631579 %
# epoch 9, minibatch 5/5, training loss -0.194612, validation loss 0.420040
#      epoch 9, minibatch 5/5, test accuracy of best model: source domain :36.363636 %, target domain 43.157895 %
# epoch 10, minibatch 5/5, training loss -0.267082, validation loss 0.353599
#      epoch 10, minibatch 5/5, test accuracy of best model: source domain :39.545455 %, target domain 45.263158 %
# epoch 11, minibatch 5/5, training loss -0.334130, validation loss 0.351472
#      epoch 11, minibatch 5/5, test accuracy of best model: source domain :38.181818 %, target domain 44.736842 %
# epoch 12, minibatch 5/5, training loss -0.273869, validation loss 0.463753
# epoch 13, minibatch 5/5, training loss -0.253568, validation loss 0.475301
# epoch 14, minibatch 5/5, training loss -0.336735, validation loss 0.436857
# epoch 15, minibatch 5/5, training loss -0.404492, validation loss 0.447450
# epoch 16, minibatch 5/5, training loss -0.353203, validation loss 0.441339
# epoch 17, minibatch 5/5, training loss -0.479581, validation loss 0.411951
# epoch 18, minibatch 5/5, training loss -0.416603, validation loss 0.459097
# epoch 19, minibatch 5/5, training loss -0.357820, validation loss 0.441891
# epoch 20, minibatch 5/5, training loss -0.337871, validation loss 0.339749
#      epoch 20, minibatch 5/5, test accuracy of best model: source domain :42.727273 %, target domain 51.052632 %
# epoch 21, minibatch 5/5, training loss -0.361864, validation loss 0.313081
#      epoch 21, minibatch 5/5, test accuracy of best model: source domain :44.090909 %, target domain 53.157895 %
# epoch 22, minibatch 5/5, training loss -0.464724, validation loss 0.392003
# epoch 23, minibatch 5/5, training loss -0.548684, validation loss 0.484501
# epoch 24, minibatch 5/5, training loss -0.454336, validation loss 0.461039
# epoch 25, minibatch 5/5, training loss -0.369239, validation loss 0.368733
# epoch 26, minibatch 5/5, training loss -0.449522, validation loss 0.328683
# epoch 27, minibatch 5/5, training loss -0.513356, validation loss 0.387925
# epoch 28, minibatch 5/5, training loss -0.462241, validation loss 0.396570
# epoch 29, minibatch 5/5, training loss -0.538336, validation loss 0.424510
# epoch 30, minibatch 5/5, training loss -0.488627, validation loss 0.458065
# epoch 31, minibatch 5/5, training loss -0.453595, validation loss 0.418502
# epoch 32, minibatch 5/5, training loss -0.505462, validation loss 0.362868
# epoch 33, minibatch 5/5, training loss -0.548818, validation loss 0.356297
# epoch 34, minibatch 5/5, training loss -0.526927, validation loss 0.382020
# epoch 35, minibatch 5/5, training loss -0.591436, validation loss 0.418613
# epoch 36, minibatch 5/5, training loss -0.608680, validation loss 0.409391
# epoch 37, minibatch 5/5, training loss -0.489297, validation loss 0.337973
# epoch 38, minibatch 5/5, training loss -0.450696, validation loss 0.342763
# epoch 39, minibatch 5/5, training loss -0.490936, validation loss 0.374988
# epoch 40, minibatch 5/5, training loss -0.511037, validation loss 0.405711
# epoch 41, minibatch 5/5, training loss -0.518314, validation loss 0.365622
# epoch 42, minibatch 5/5, training loss -0.548191, validation loss 0.337395
# epoch 43, minibatch 5/5, training loss -0.483627, validation loss 0.362215
# epoch 44, minibatch 5/5, training loss -0.526812, validation loss 0.451856
# epoch 45, minibatch 5/5, training loss -0.451056, validation loss 0.447137
# epoch 46, minibatch 5/5, training loss -0.490996, validation loss 0.357190
# epoch 47, minibatch 5/5, training loss -0.552802, validation loss 0.299052
#      epoch 47, minibatch 5/5, test accuracy of best model: source domain :40.909091 %, target domain 48.421053 %
# epoch 48, minibatch 5/5, training loss -0.552122, validation loss 0.340212
# epoch 49, minibatch 5/5, training loss -0.640802, validation loss 0.389546
# epoch 50, minibatch 5/5, training loss -0.597264, validation loss 0.448868
# epoch 51, minibatch 5/5, training loss -0.489791, validation loss 0.385752
# epoch 52, minibatch 5/5, training loss -0.520320, validation loss 0.283154
#      epoch 52, minibatch 5/5, test accuracy of best model: source domain :43.636364 %, target domain 49.473684 %
# epoch 53, minibatch 5/5, training loss -0.556642, validation loss 0.205238
#      epoch 53, minibatch 5/5, test accuracy of best model: source domain :41.818182 %, target domain 47.894737 %
# epoch 54, minibatch 5/5, training loss -0.522684, validation loss 0.257307
# epoch 55, minibatch 5/5, training loss -0.496555, validation loss 0.344685
# epoch 56, minibatch 5/5, training loss -0.561581, validation loss 0.417579
# epoch 57, minibatch 5/5, training loss -0.619169, validation loss 0.399419
# epoch 58, minibatch 5/5, training loss -0.645197, validation loss 0.360383
# epoch 59, minibatch 5/5, training loss -0.604592, validation loss 0.352698
# epoch 60, minibatch 5/5, training loss -0.530049, validation loss 0.281814
# epoch 61, minibatch 5/5, training loss -0.475507, validation loss 0.339023
# epoch 62, minibatch 5/5, training loss -0.550110, validation loss 0.433282
# epoch 63, minibatch 5/5, training loss -0.687157, validation loss 0.447279
# epoch 64, minibatch 5/5, training loss -0.624318, validation loss 0.420214
# epoch 65, minibatch 5/5, training loss -0.568644, validation loss 0.377475
# epoch 66, minibatch 5/5, training loss -0.555995, validation loss 0.367272
# epoch 67, minibatch 5/5, training loss -0.573126, validation loss 0.383624
# epoch 68, minibatch 5/5, training loss -0.562957, validation loss 0.401504
# epoch 69, minibatch 5/5, training loss -0.605999, validation loss 0.403948
# epoch 70, minibatch 5/5, training loss -0.630010, validation loss 0.349707
# epoch 71, minibatch 5/5, training loss -0.594089, validation loss 0.320180
# epoch 72, minibatch 5/5, training loss -0.568614, validation loss 0.315498
# epoch 73, minibatch 5/5, training loss -0.611589, validation loss 0.342242
# epoch 74, minibatch 5/5, training loss -0.593200, validation loss 0.378103
# epoch 75, minibatch 5/5, training loss -0.626025, validation loss 0.394463
# epoch 76, minibatch 5/5, training loss -0.634097, validation loss 0.429841
# epoch 77, minibatch 5/5, training loss -0.602923, validation loss 0.456854
# epoch 78, minibatch 5/5, training loss -0.640326, validation loss 0.428275
# epoch 79, minibatch 5/5, training loss -0.604081, validation loss 0.419141
# epoch 80, minibatch 5/5, training loss -0.618950, validation loss 0.369761
# epoch 81, minibatch 5/5, training loss -0.609222, validation loss 0.358399
# epoch 82, minibatch 5/5, training loss -0.614015, validation loss 0.314321
# epoch 83, minibatch 5/5, training loss -0.616304, validation loss 0.363508
# epoch 84, minibatch 5/5, training loss -0.606620, validation loss 0.415615
# epoch 85, minibatch 5/5, training loss -0.623632, validation loss 0.415881
# epoch 86, minibatch 5/5, training loss -0.611263, validation loss 0.434111
# epoch 87, minibatch 5/5, training loss -0.592354, validation loss 0.430012
# epoch 88, minibatch 5/5, training loss -0.616210, validation loss 0.373745
# epoch 89, minibatch 5/5, training loss -0.630021, validation loss 0.356788
# epoch 90, minibatch 5/5, training loss -0.628460, validation loss 0.382897
# epoch 91, minibatch 5/5, training loss -0.608077, validation loss 0.370893
# epoch 92, minibatch 5/5, training loss -0.633473, validation loss 0.364513
# epoch 93, minibatch 5/5, training loss -0.638128, validation loss 0.371881
# epoch 94, minibatch 5/5, training loss -0.667200, validation loss 0.374012
# epoch 95, minibatch 5/5, training loss -0.661876, validation loss 0.387479
# epoch 96, minibatch 5/5, training loss -0.691355, validation loss 0.402421
# epoch 97, minibatch 5/5, training loss -0.659175, validation loss 0.438851
# epoch 98, minibatch 5/5, training loss -0.617331, validation loss 0.438355
# epoch 99, minibatch 5/5, training loss -0.638164, validation loss 0.425288
# epoch 100, minibatch 5/5, training loss -0.665452, validation loss 0.392468
# Optimization complete. Best validation loss of 0.205238 obtained at iteration 265, with train loss -0.556642
# train accuracy : source domain 99.824561 %, target domain  42.061856 %
# validation accuracy : source domain 41.515152 %, target domain  46.785714 %
# test accuracy : source domain 41.818182 %, target domain  47.894737 %
# 99.82 - 41.52 - 41.82; 42.06 - 46.79 - 47.89
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 1
# DomainClassifier is constructed with hidden layer number 0
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 1061, '...']
# ['Computing P-values for point ', 500, ' of ', 1061, '...']
# ['Computing P-values for point ', 1000, ' of ', 1061, '...']
# ['Mean value of sigma: ', 1.0888708042034396]
