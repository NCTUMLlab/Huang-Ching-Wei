# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from __future__ import print_function
from collections import OrderedDict

import os
import sys
import timeit
import pickle


import scipy.io as sio
import numpy as np
import theano
import theano.tensor as T

sys.path.insert(0, "/home/cwhuang/DVTL/Model/")
import nnet as nn
import criteria	as er
import util
import DSSL

import OfficeFeaturePlot as fp
# Out:
# Using gpu device 0: GeForce GTX TITAN (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5005)

# %%
'''Model Construct'''
if __name__ == '__main__':
    
    source_file = '/home/cwhuang/DVTL/Dataset/Office/Caltech10_SURF_L10.npy'
    target_file = '/home/cwhuang/DVTL/Dataset/Office/amazon_SURF_L10.npy'

    source_data = np.load(source_file)
    target_data = np.load(target_file)
    
    #source_data, target_data = DataDuplicate.DataDuplicate(source_data, target_data)
    
    ########################################################################
    ###                        Coefficient Initial                       ###
    ########################################################################        

    x_dim = 800
    y_dim = 10
    z_dim = 100                #dimension of latent feature    
    h_dim = 300             #dimension of hidden unit      
    activation = T.nnet.sigmoid
    lr = 0.005

    struct = DSSL.DSSL_struct()        
    struct.encoder.layer_dim = [x_dim, h_dim, z_dim]
    struct.encoder.activation = [activation, activation]
    struct.encoder.learning_rate = [lr, lr]
    struct.encoder.decay = [1, 1]                
    struct.classifier.layer_dim = [z_dim, y_dim]
    struct.classifier.activation = [T.nnet.softmax]   
    struct.classifier.learning_rate = [lr, lr]
    struct.classifier.decay = [1, 1]
    struct.decoder.layer_dim = [z_dim, h_dim, x_dim]
    struct.decoder.activation = [activation, activation ]   
    struct.decoder.learning_rate = [lr, lr]
    struct.decoder.decay = [1, 1]    
    
    coef = DSSL.DSSL_coef(    
        alpha = 2,
        beta = 2,
        D = 500,
        optimize = 'Adam_update'        
    )        
    
    isMMD = 'MMD_'
    if coef.beta == 0:
        isMMD = ''                
    description = 'Office_DSSL_%s%s' % (isMMD, coef.optimize)
        
    features_model, test_model, trained_param = DSSL.DSSL_training(
        source_data = source_data,
        target_data = target_data,
        n_train_batches = 10,
        n_epochs=100,
        struct = struct,
        coef = coef,
        description = description
    )
    
    fp.features_plot(features_model, test_model, source_data, target_data, description)
# Out:
# number of minibatch at one epoch: 10, batch size source : 57, target : 48
#  validation size, S:330, T:280, test size, S:220, T:190
# ... building the model
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# ... training
# Initial, test accuracy: source domain :8.181818 %, target domain 8.947368 %
# epoch 1, minibatch 10/10, training loss 129.581053, validation loss 129.590220
#      epoch 1, minibatch 10/10, test accuracy of best model: source domain :20.454545 %, target domain 23.157895 %
# epoch 2, minibatch 10/10, training loss 128.956228, validation loss 129.110408
#      epoch 2, minibatch 10/10, test accuracy of best model: source domain :28.181818 %, target domain 27.894737 %
# epoch 3, minibatch 10/10, training loss 128.545537, validation loss 128.971055
#      epoch 3, minibatch 10/10, test accuracy of best model: source domain :29.545455 %, target domain 32.105263 %
# epoch 4, minibatch 10/10, training loss 128.149911, validation loss 128.828211
#      epoch 4, minibatch 10/10, test accuracy of best model: source domain :36.818182 %, target domain 40.000000 %
# epoch 5, minibatch 10/10, training loss 127.819218, validation loss 128.726506
#      epoch 5, minibatch 10/10, test accuracy of best model: source domain :41.818182 %, target domain 41.578947 %
# epoch 6, minibatch 10/10, training loss 127.575484, validation loss 128.637818
#      epoch 6, minibatch 10/10, test accuracy of best model: source domain :43.181818 %, target domain 48.421053 %
# epoch 7, minibatch 10/10, training loss 127.361927, validation loss 128.577921
#      epoch 7, minibatch 10/10, test accuracy of best model: source domain :44.545455 %, target domain 47.368421 %
# epoch 8, minibatch 10/10, training loss 127.197349, validation loss 128.548371
#      epoch 8, minibatch 10/10, test accuracy of best model: source domain :44.545455 %, target domain 46.315789 %
# epoch 9, minibatch 10/10, training loss 127.063983, validation loss 128.490015
#      epoch 9, minibatch 10/10, test accuracy of best model: source domain :47.727273 %, target domain 47.368421 %
# epoch 10, minibatch 10/10, training loss 126.957289, validation loss 128.458868
#      epoch 10, minibatch 10/10, test accuracy of best model: source domain :47.272727 %, target domain 48.947368 %
# epoch 11, minibatch 10/10, training loss 126.858907, validation loss 128.455252
#      epoch 11, minibatch 10/10, test accuracy of best model: source domain :47.272727 %, target domain 46.842105 %
# epoch 12, minibatch 10/10, training loss 126.798927, validation loss 128.406647
#      epoch 12, minibatch 10/10, test accuracy of best model: source domain :47.727273 %, target domain 50.526316 %
# epoch 13, minibatch 10/10, training loss 126.742892, validation loss 128.398593
#      epoch 13, minibatch 10/10, test accuracy of best model: source domain :46.818182 %, target domain 48.421053 %
# epoch 14, minibatch 10/10, training loss 126.692874, validation loss 128.378863
#      epoch 14, minibatch 10/10, test accuracy of best model: source domain :46.363636 %, target domain 49.473684 %
# epoch 15, minibatch 10/10, training loss 126.647158, validation loss 128.378473
#      epoch 15, minibatch 10/10, test accuracy of best model: source domain :45.000000 %, target domain 48.947368 %
# epoch 16, minibatch 10/10, training loss 126.623948, validation loss 128.340424
#      epoch 16, minibatch 10/10, test accuracy of best model: source domain :43.181818 %, target domain 46.842105 %
# epoch 17, minibatch 10/10, training loss 126.568945, validation loss 128.373425
# epoch 18, minibatch 10/10, training loss 126.529457, validation loss 128.326152
#      epoch 18, minibatch 10/10, test accuracy of best model: source domain :42.727273 %, target domain 47.368421 %
# epoch 19, minibatch 10/10, training loss 126.505339, validation loss 128.318338
#      epoch 19, minibatch 10/10, test accuracy of best model: source domain :42.727273 %, target domain 46.842105 %
# epoch 20, minibatch 10/10, training loss 126.472576, validation loss 128.322998
# epoch 21, minibatch 10/10, training loss 126.447730, validation loss 128.308618
#      epoch 21, minibatch 10/10, test accuracy of best model: source domain :42.272727 %, target domain 45.263158 %
# epoch 22, minibatch 10/10, training loss 126.416149, validation loss 128.339076
# epoch 23, minibatch 10/10, training loss 126.394978, validation loss 128.304514
#      epoch 23, minibatch 10/10, test accuracy of best model: source domain :43.636364 %, target domain 47.894737 %
# epoch 24, minibatch 10/10, training loss 126.378600, validation loss 128.308452
# epoch 25, minibatch 10/10, training loss 126.352945, validation loss 128.330862
# epoch 26, minibatch 10/10, training loss 126.330960, validation loss 128.321090
# epoch 27, minibatch 10/10, training loss 126.333809, validation loss 128.293861
#      epoch 27, minibatch 10/10, test accuracy of best model: source domain :42.727273 %, target domain 48.421053 %
# epoch 28, minibatch 10/10, training loss 126.300549, validation loss 128.319897
# epoch 29, minibatch 10/10, training loss 126.278031, validation loss 128.297420
# epoch 30, minibatch 10/10, training loss 126.264249, validation loss 128.303297
# epoch 31, minibatch 10/10, training loss 126.253451, validation loss 128.291966
#      epoch 31, minibatch 10/10, test accuracy of best model: source domain :44.545455 %, target domain 45.263158 %
# epoch 32, minibatch 10/10, training loss 126.235517, validation loss 128.322020
# epoch 33, minibatch 10/10, training loss 126.209979, validation loss 128.291518
#      epoch 33, minibatch 10/10, test accuracy of best model: source domain :43.636364 %, target domain 48.421053 %
# epoch 34, minibatch 10/10, training loss 126.214480, validation loss 128.320296
# epoch 35, minibatch 10/10, training loss 126.194676, validation loss 128.300380
# epoch 36, minibatch 10/10, training loss 126.173894, validation loss 128.287588
#      epoch 36, minibatch 10/10, test accuracy of best model: source domain :43.636364 %, target domain 45.263158 %
# epoch 37, minibatch 10/10, training loss 126.173810, validation loss 128.327876
# epoch 38, minibatch 10/10, training loss 126.155214, validation loss 128.291347
# epoch 39, minibatch 10/10, training loss 126.144798, validation loss 128.336719
# epoch 40, minibatch 10/10, training loss 126.133323, validation loss 128.296875
# epoch 41, minibatch 10/10, training loss 126.118984, validation loss 128.324713
# epoch 42, minibatch 10/10, training loss 126.115375, validation loss 128.304734
# epoch 43, minibatch 10/10, training loss 126.115535, validation loss 128.296244
# epoch 44, minibatch 10/10, training loss 126.095103, validation loss 128.313727
# epoch 45, minibatch 10/10, training loss 126.090041, validation loss 128.302090
# epoch 46, minibatch 10/10, training loss 126.086988, validation loss 128.323294
# epoch 47, minibatch 10/10, training loss 126.066407, validation loss 128.293019
# epoch 48, minibatch 10/10, training loss 126.052451, validation loss 128.358542
# epoch 49, minibatch 10/10, training loss 126.048039, validation loss 128.319753
# epoch 50, minibatch 10/10, training loss 126.044201, validation loss 128.284652
#      epoch 50, minibatch 10/10, test accuracy of best model: source domain :40.909091 %, target domain 46.842105 %
# epoch 51, minibatch 10/10, training loss 126.021788, validation loss 128.335793
# epoch 52, minibatch 10/10, training loss 126.032330, validation loss 128.291601
# epoch 53, minibatch 10/10, training loss 126.034582, validation loss 128.327495
# epoch 54, minibatch 10/10, training loss 126.007030, validation loss 128.311264
# epoch 55, minibatch 10/10, training loss 126.003674, validation loss 128.298985
# epoch 56, minibatch 10/10, training loss 126.005391, validation loss 128.356198
# epoch 57, minibatch 10/10, training loss 125.995278, validation loss 128.332209
# epoch 58, minibatch 10/10, training loss 125.990970, validation loss 128.309462
# epoch 59, minibatch 10/10, training loss 125.972773, validation loss 128.364947
# epoch 60, minibatch 10/10, training loss 125.975007, validation loss 128.309446
# epoch 61, minibatch 10/10, training loss 125.963376, validation loss 128.351139
# epoch 62, minibatch 10/10, training loss 125.973132, validation loss 128.366975
# epoch 63, minibatch 10/10, training loss 125.961527, validation loss 128.353614
# epoch 64, minibatch 10/10, training loss 125.940040, validation loss 128.373500
# epoch 65, minibatch 10/10, training loss 125.957848, validation loss 128.372927
# epoch 66, minibatch 10/10, training loss 125.941963, validation loss 128.363081
# epoch 67, minibatch 10/10, training loss 125.934928, validation loss 128.374463
# epoch 68, minibatch 10/10, training loss 125.937045, validation loss 128.367331
# epoch 69, minibatch 10/10, training loss 125.934831, validation loss 128.378754
# epoch 70, minibatch 10/10, training loss 125.933348, validation loss 128.450072
# epoch 71, minibatch 10/10, training loss 125.916460, validation loss 128.381330
# epoch 72, minibatch 10/10, training loss 125.915145, validation loss 128.394847
# epoch 73, minibatch 10/10, training loss 125.898884, validation loss 128.397296
# epoch 74, minibatch 10/10, training loss 125.901168, validation loss 128.405233
# epoch 75, minibatch 10/10, training loss 125.905328, validation loss 128.395811
# epoch 76, minibatch 10/10, training loss 125.903454, validation loss 128.437028
# epoch 77, minibatch 10/10, training loss 125.895217, validation loss 128.416416
# epoch 78, minibatch 10/10, training loss 125.892249, validation loss 128.415944
# epoch 79, minibatch 10/10, training loss 125.878600, validation loss 128.427111
# epoch 80, minibatch 10/10, training loss 125.885133, validation loss 128.399922
# epoch 81, minibatch 10/10, training loss 125.887752, validation loss 128.497881
# epoch 82, minibatch 10/10, training loss 125.869351, validation loss 128.408086
# epoch 83, minibatch 10/10, training loss 125.864172, validation loss 128.461678
# epoch 84, minibatch 10/10, training loss 125.859382, validation loss 128.416034
# epoch 85, minibatch 10/10, training loss 125.847138, validation loss 128.471459
# epoch 86, minibatch 10/10, training loss 125.852594, validation loss 128.400138
# epoch 87, minibatch 10/10, training loss 125.852019, validation loss 128.444033
# epoch 88, minibatch 10/10, training loss 125.853207, validation loss 128.448217
# epoch 89, minibatch 10/10, training loss 125.845227, validation loss 128.420179
# epoch 90, minibatch 10/10, training loss 125.831824, validation loss 128.438664
# epoch 91, minibatch 10/10, training loss 125.835814, validation loss 128.403657
# epoch 92, minibatch 10/10, training loss 125.841829, validation loss 128.484932
# epoch 93, minibatch 10/10, training loss 125.837067, validation loss 128.449296
# epoch 94, minibatch 10/10, training loss 125.828419, validation loss 128.417771
# epoch 95, minibatch 10/10, training loss 125.828206, validation loss 128.489563
# epoch 96, minibatch 10/10, training loss 125.816496, validation loss 128.454605
# epoch 97, minibatch 10/10, training loss 125.819444, validation loss 128.475866
# epoch 98, minibatch 10/10, training loss 125.812411, validation loss 128.473776
# epoch 99, minibatch 10/10, training loss 125.810207, validation loss 128.470942
# epoch 100, minibatch 10/10, training loss 125.811755, validation loss 128.495100
# Optimization complete. Best validation loss of 128.284652 obtained at iteration 500, with train loss 126.044201
# train accuracy : source domain 100.000000 %, target domain  27.708333 %
# validation accuracy : source domain 42.727273 %, target domain  41.785714 %
# test accuracy : source domain 40.909091 %, target domain  46.842105 %
# 100.00 - 42.73 - 40.91; 27.71 - 41.79 - 46.84
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Encoder is constructed with hidden layer number 1
# Classifier is constructed with hidden layer number 0
# Decoder is constructed with hidden layer number 1
# Preprocessing the data using PCA...
# Computing pairwise distances...
# ['Computing P-values for point ', 0, ' of ', 1061, '...']
# ['Computing P-values for point ', 500, ' of ', 1061, '...']
# ['Computing P-values for point ', 1000, ' of ', 1061, '...']
# ['Mean value of sigma: ', 1.0036821005377727]
